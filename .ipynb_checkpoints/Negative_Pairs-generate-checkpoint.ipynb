# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from scipy.sparse import csr_matrix, lil_matrix
from scipy import sparse
from abc import ABCMeta, abstractmethod
from scipy.stats import randint as sp_randint
import random

# %%
# !pip install -q xlrd
# !git clone https://github.com/mansisinha/taddhita.git
# Out:
# fatal: destination path 'taddhita' already exists and is not an empty directory.

# %%
# !ls taddhita/newPairs.txt
# Out:
# taddhita/newPairs.txt

# %%
import pandas as pd
url='https://raw.githubusercontent.com/mansisinha/taddhita/master/allPairs.csv'

df=pd.read_csv(url)
df.drop(['affix','word','sense','meaning','Source Word Count','Derived word count','word_y'],axis=1,inplace=True)
#df['n']=1
df
#df.groupby('Affix').count()
# Out:
#      Affix   Source Word    Derived Word
# 0       ly       selfish       selfishly
# 1       ly      virulent      virulently
# 2       ly        gentle          gently
# 3       ly    harmonious    harmoniously
# 4       ly       guarded       guardedly
# 5       ly       gushing       gushingly
# 6       ly      habitual      habitually
# 7       ly         handy         handily
# 8       ly     haphazard     haphazardly
# 9       ly         happy         happily
# 10      ly       harmful       harmfully
# 11      ly      harmless      harmlessly
# 12      ly         harsh         harshly
# 13      ly      grudging      grudgingly
# 14      ly         hasty         hastily
# 15      ly     hazardous     hazardously
# 16      ly         hedly          headly
# 17      ly     healthful     healthfully
# 18      ly       healthy       healthily
# 19      ly     genocidal     genocidally
# 20      ly  foundational  foundationally
# 21      ly     fortunate     fortunately
# 22      ly          fond          fondly
# 23      ly     voiceless     voicelessly
# 24      ly    vociferous    vociferously
# 25      ly         vocal         vocally
# 26      ly    viviparous    viviparously
# 27      ly         vivid         vividly
# 28      ly     vivacious     vivaciously
# 29      ly       visible         visibly
# ...    ...           ...             ...
# 7485   ism    terrorisme       terrorism
# 7486   ism          lyre          lyrism
# 7487     y           pig           piggy
# 7488     y          pike           pikey
# 7489     y           pom           pommy
# 7490     y         prose           prosy
# 7491     y  ambidextrous            amby
# 7492     y           dun           dunny
# 7493     y          goon           goony
# 7494     y          mess           messy
# 7495     y        ignore            iggy
# 7496     y        nigger           niggy
# 7497     y          hunk           hunky
# 7498   ism      plagiary      plagiarism
# 7499   ism     commensal    commensalism
# 7500   ous         usury        usurious
# 7501   ism          tour         tourism
# 7502   ism     triumphal    triumphalism
# 7503   ism      creation     creationism
# 7504   ous          cone      coniferous
# 7505   ous      idolatry      idolatrous
# 7506   ous        fibrin       fibrinous
# 7507   ous       festive       festivous
# 7508  wise           fan         fanwise
# 7509   ous        clamor       clamorous
# 7510   ous    androgynus     androgynous
# 7511   ous       albumin      albuminous
# 7512   ous       acronym      acronymous
# 7513   ous       alumina       aluminous
# 7514   ous     pseudonym    pseudonymous
#
# [7515 rows x 3 columns]

# %%
# Iterative longest contiguous sequence. No one character matchings
def lcs(s1,s2):
    longest = ""
    i = 0
    for x in s1:
        if re.search(x, s2):
          s = x
          while re.search(s, s2):
            if len(s)>len(longest):
                longest = s
            if i+len(s) == len(s1):
                break
            s = s1[i:i+len(s)+1]
        i += 1
    return longest

def iterLCS(pdf):
    posCounter = 1
    sw1Orig = pdf['Source Word']
    sw2Orig = pdf['Derived Word']
    sw1 = pdf['Source Word']
    sw2 = pdf['Derived Word']
    longDict = dict()
    prevSInd = 0
    prevTInd = 0
    rejLength =0
    
    while True:
        tempVal = lcs(sw1Orig,sw2Orig)
        if len(tempVal)  <= 1:
            break
        
        tempSInd =  pdf['Source Word'].find(tempVal) + 1
        tempTInd =  pdf['Derived Word'].find(tempVal) + 1
        if (tempSInd - prevSInd)*(tempTInd - prevTInd) < 0:
            print('here',tempVal,pdf['Source Word'],pdf['Derived Word'])
            sw1Orig = sw1Orig.replace(tempVal,'~~',1)
            sw2Orig = sw2Orig.replace(tempVal,'^^',1)
            rejLength += len(tempVal)
        else:
            longDict[tempSInd] = tempVal+'#'+str(posCounter)
            sw1 = sw1.replace(tempVal,'#'+str(posCounter)+'#',1)
            sw2 = sw2.replace(tempVal,'!'+str(posCounter)+'!',1)
            sw1Orig = sw1Orig.replace(tempVal,'~'+str(posCounter)+'~',1)
            sw2Orig = sw2Orig.replace(tempVal,'^'+str(posCounter)+'^',1)
            prevSInd = tempSInd + 1
            prevTInd = tempTInd + 1
            posCounter += 1
    
    #return [longList,[item for item in sw1.split('#') if len(item) > 0],[item for item in sw2.split('!') if len(item) > 0]]
    pdf['common'] = longDict
    pdf['deleted'] = [item for item in sw1.split('#') if len(item) > 0 and item.isdigit()!=True ]
    pdf['sourceSkeleton'] = sw1
    pdf['targetSkeleton'] = sw2
    

    jointWord = ''
    sw1Split = sw1.split('#')
    sw2Split = sw2.split('!')
    
    sw3 = [nummi for nummi in sw1Split if nummi.isdigit() == True]
    sw4 = [nummi for nummi in sw2Split if nummi.isdigit() == True]
    
    if sw3!=sw4:
            print('ordermatchilla',sw3,sw4)
    

    for key in sorted(longDict.keys()):
        nowN = longDict[key].split('#')[1]
        try:
            
            while sw1Split[0] != nowN:
            
                tingi = sw1Split.pop(0)
                if len(tingi) > 0:
                    
                    jointWord += 'DEL('
                    for cahra in tingi:
                        jointWord += cahra
                    jointWord += ')'
        except IndexError:
            print("SW1",pdf['Source Word'])
                
        try:
            while sw2Split[0] != nowN:
                tingi = sw2Split.pop(0)
                if len(tingi) > 0:
                    jointWord += 'INS('
                    for cahra in tingi:
                        jointWord += cahra
                    jointWord += ')'
        except IndexError:
            print("SW2",pdf['source'])
            
            
        try:    
            if  sw1Split[0] == nowN and  sw2Split[0] == nowN:
                jointWord = jointWord + longDict[key].split('#')[0]
                sw1Split.pop(0)
                sw2Split.pop(0)
            else:
                print('pani pali not expected')
        except IndexError:
            print("common",pdf['Source Word'])
                
    while len(sw1Split) > 0:
        tingi = sw1Split.pop(0)
        if len(tingi) > 0:
            jointWord += 'DEL('
            for cahra in tingi:
                jointWord += cahra
            jointWord += ')'
            
    while len(sw2Split) > 0:
        
        tingi = sw2Split.pop(0)
        if len(tingi) > 0:
            jointWord += 'INS('
            for cahra in tingi:
                jointWord += cahra
            jointWord += ')'

    
    if len(pdf['deleted']) == 0:
        pdf['deleted'] = ['ϵ']
    
    
    pdf['added'] = [item for item in sw2.split('!') if len(item) > 0 and item.isdigit()!=True]
    
    if len(pdf['added']) == 0:
        pdf['added'] = ['ϵ']
        
    pdf['aligned'] = jointWord
    
    return pdf
    
#iterLCS(ppd.iloc[3865,:])

# %%
import re
df12=df.sample(frac=1)
ddf = df12.apply(iterLCS, axis=1)

# %%
ddf
# Out:
#      Affix     Source Word      Derived Word                  common deleted  \
# 3518  ness      compulsive    compulsiveness     {1: 'compulsive#1'}     [ϵ]
# 5260    ly            week            weekly           {1: 'week#1'}     [ϵ]
# 3199    ic          allele           allelic          {1: 'allel#1'}     [e]
# 4411   man          camera         cameraman         {1: 'camera#1'}     [ϵ]
# 60      ly           green           greenly          {1: 'green#1'}     [ϵ]
# 2093    er         refound         refounder        {1: 'refound#1'}     [ϵ]
# 4773    or     hallucinate      hallucinator     {1: 'hallucinat#1'}     [e]
# 3666    er             low             lower            {1: 'low#1'}     [ϵ]
# 5736    al        aperture         apertural        {1: 'apertur#1'}     [e]
# 7322   ise        standard       standardise       {1: 'standard#1'}     [ϵ]
# 2796   ist  histopathology  histopathologist  {1: 'histopatholog#1'}     [y]
# 1072    ly        inferior        inferiorly       {1: 'inferior#1'}     [ϵ]
# 1686    er           douse            douser          {1: 'douse#1'}     [ϵ]
# 3339    ic            mora            moraic           {1: 'mora#1'}     [ϵ]
# 1102    ly   intertemporal   intertemporally  {1: 'intertemporal#1'}     [ϵ]
# 2505  ness      abstemious    abstemiousness     {1: 'abstemious#1'}     [ϵ]
# 5452   let             app            applet            {1: 'app#1'}     [ϵ]
# 1977    er          secede           seceder         {1: 'secede#1'}     [ϵ]
# 1592    er            gnaw            gnawer           {1: 'gnaw#1'}     [ϵ]
# 3298    ic            base             basic            {1: 'bas#1'}     [e]
# 2589  ness             shy           shyness            {1: 'shy#1'}     [ϵ]
# 806     ly       legendary       legendarily       {1: 'legendar#1'}     [y]
# 2584  ness          second        secondness         {1: 'second#1'}     [ϵ]
# 4254    ic      encephalon        encephalic       {1: 'encephal#1'}    [on]
# 1006    ly        manifest        manifestly       {1: 'manifest#1'}     [ϵ]
# 2248    er             cum            cummer            {1: 'cum#1'}     [ϵ]
# 4396   man             tub            tubman            {1: 'tub#1'}     [ϵ]
# 6492   ize          formal         formalize         {1: 'formal#1'}     [ϵ]
# 4969  ical         monarch       monarchical        {1: 'monarch#1'}     [ϵ]
# 2118    er          squeak          squeaker         {1: 'squeak#1'}     [ϵ]
# ...    ...             ...               ...                     ...     ...
# 5507    ly        archival        archivally       {1: 'archival#1'}     [ϵ]
# 3634    er         crumple          crumpler        {1: 'crumple#1'}     [ϵ]
# 2133    er          repent          repenter         {1: 'repent#1'}     [ϵ]
# 4019  ness          boring        boringness         {1: 'boring#1'}     [ϵ]
# 2620  ness          chosen        chosenness         {1: 'chosen#1'}     [ϵ]
# 366     ly    overwhelming    overwhelmingly   {1: 'overwhelming#1'}     [ϵ]
# 6742   ize       editorial      editorialize      {1: 'editorial#1'}     [ϵ]
# 7407  wise            case          casewise           {1: 'case#1'}     [ϵ]
# 5798   ism        revision       revisionism       {1: 'revision#1'}     [ϵ]
# 4310  ness      forthright    forthrightness     {1: 'forthright#1'}     [ϵ]
# 1514    er         explain         explainer        {1: 'explain#1'}     [ϵ]
# 5276    ly      capacitive      capacitively     {1: 'capacitive#1'}     [ϵ]
# 6054     y           pinch            pinchy          {1: 'pinch#1'}     [ϵ]
# 616     ly     inexcusable       inexcusably     {1: 'inexcusabl#1'}     [e]
# 6656   oid          fibrin         fibrinoid         {1: 'fibrin#1'}     [ϵ]
# 2406  ness      transitory    transitoriness      {1: 'transitor#1'}     [y]
# 5998    er         engrave          engraver        {1: 'engrave#1'}     [ϵ]
# 3312    ic    promyelocyte     promyelocytic    {1: 'promyelocyt#1'}     [e]
# 7405  wise           piece         piecewise          {1: 'piece#1'}     [ϵ]
# 4399   man           yacht         yachtsman          {1: 'yacht#1'}     [ϵ]
# 207     ly    invigorating    invigoratingly   {1: 'invigorating#1'}     [ϵ]
# 2442  ness         genuine       genuineness        {1: 'genuine#1'}     [ϵ]
# 3311    ic      pareidolia        pareidolic      {1: 'pareidoli#1'}     [a]
# 3036    ly      consistent      consistently     {1: 'consistent#1'}     [ϵ]
# 5437    al    denomination    denominational   {1: 'denomination#1'}     [ϵ]
# 3544    er           smell           smeller          {1: 'smell#1'}     [ϵ]
# 7461    ic         anarchy          anarchic         {1: 'anarch#1'}     [y]
# 6248  ical      deontology     deontological      {1: 'deontolog#1'}     [y]
# 4842    ee           serve            servee          {1: 'serve#1'}     [ϵ]
# 1697    er           drill           driller          {1: 'drill#1'}     [ϵ]
#
#      sourceSkeleton targetSkeleton    added                      aligned
# 3518            #1#        !1!ness   [ness]          compulsiveINS(ness)
# 5260            #1#          !1!ly     [ly]                  weekINS(ly)
# 3199           #1#e          !1!ic     [ic]           allelDEL(e)INS(ic)
# 4411            #1#         !1!man    [man]               cameraINS(man)
# 60              #1#          !1!ly     [ly]                 greenINS(ly)
# 2093            #1#          !1!er     [er]               refoundINS(er)
# 4773           #1#e          !1!or     [or]      hallucinatDEL(e)INS(or)
# 3666            #1#          !1!er     [er]                   lowINS(er)
# 5736           #1#e          !1!al     [al]         aperturDEL(e)INS(al)
# 7322            #1#         !1!ise    [ise]             standardINS(ise)
# 2796           #1#y         !1!ist    [ist]  histopathologDEL(y)INS(ist)
# 1072            #1#          !1!ly     [ly]              inferiorINS(ly)
# 1686            #1#           !1!r      [r]                  douseINS(r)
# 3339            #1#          !1!ic     [ic]                  moraINS(ic)
# 1102            #1#          !1!ly     [ly]         intertemporalINS(ly)
# 2505            #1#        !1!ness   [ness]          abstemiousINS(ness)
# 5452            #1#         !1!let    [let]                  appINS(let)
# 1977            #1#           !1!r      [r]                 secedeINS(r)
# 1592            #1#          !1!er     [er]                  gnawINS(er)
# 3298           #1#e          !1!ic     [ic]             basDEL(e)INS(ic)
# 2589            #1#        !1!ness   [ness]                 shyINS(ness)
# 806            #1#y         !1!ily    [ily]       legendarDEL(y)INS(ily)
# 2584            #1#        !1!ness   [ness]              secondINS(ness)
# 4254          #1#on          !1!ic     [ic]       encephalDEL(on)INS(ic)
# 1006            #1#          !1!ly     [ly]              manifestINS(ly)
# 2248            #1#         !1!mer    [mer]                  cumINS(mer)
# 4396            #1#         !1!man    [man]                  tubINS(man)
# 6492            #1#         !1!ize    [ize]               formalINS(ize)
# 4969            #1#        !1!ical   [ical]             monarchINS(ical)
# 2118            #1#          !1!er     [er]                squeakINS(er)
# ...             ...            ...      ...                          ...
# 5507            #1#          !1!ly     [ly]              archivalINS(ly)
# 3634            #1#           !1!r      [r]                crumpleINS(r)
# 2133            #1#          !1!er     [er]                repentINS(er)
# 4019            #1#        !1!ness   [ness]              boringINS(ness)
# 2620            #1#        !1!ness   [ness]              chosenINS(ness)
# 366             #1#          !1!ly     [ly]          overwhelmingINS(ly)
# 6742            #1#         !1!ize    [ize]            editorialINS(ize)
# 7407            #1#        !1!wise   [wise]                caseINS(wise)
# 5798            #1#         !1!ism    [ism]             revisionINS(ism)
# 4310            #1#        !1!ness   [ness]          forthrightINS(ness)
# 1514            #1#          !1!er     [er]               explainINS(er)
# 5276            #1#          !1!ly     [ly]            capacitiveINS(ly)
# 6054            #1#           !1!y      [y]                  pinchINS(y)
# 616            #1#e           !1!y      [y]       inexcusablDEL(e)INS(y)
# 6656            #1#         !1!oid    [oid]               fibrinINS(oid)
# 2406           #1#y       !1!iness  [iness]    transitorDEL(y)INS(iness)
# 5998            #1#           !1!r      [r]                engraveINS(r)
# 3312           #1#e          !1!ic     [ic]     promyelocytDEL(e)INS(ic)
# 7405            #1#        !1!wise   [wise]               pieceINS(wise)
# 4399            #1#        !1!sman   [sman]               yachtINS(sman)
# 207             #1#          !1!ly     [ly]          invigoratingINS(ly)
# 2442            #1#        !1!ness   [ness]             genuineINS(ness)
# 3311           #1#a           !1!c      [c]        pareidoliDEL(a)INS(c)
# 3036            #1#          !1!ly     [ly]            consistentINS(ly)
# 5437            #1#          !1!al     [al]          denominationINS(al)
# 3544            #1#          !1!er     [er]                 smellINS(er)
# 7461           #1#y          !1!ic     [ic]          anarchDEL(y)INS(ic)
# 6248           #1#y        !1!ical   [ical]     deontologDEL(y)INS(ical)
# 4842            #1#           !1!e      [e]                  serveINS(e)
# 1697            #1#          !1!er     [er]                 drillINS(er)
#
# [7515 rows x 9 columns]

# %%
pattern ={}
for index, row in ddf.iterrows():
    if row['targetSkeleton'] in pattern:
            pattern[row['targetSkeleton']]
            if row['sourceSkeleton'] in pattern[row['targetSkeleton']]:
                pattern[row['targetSkeleton']][row['sourceSkeleton']].add(row['Affix'])
            else:
                pattern[row['targetSkeleton']][row['sourceSkeleton']]={row['Affix']}                
    else:
        pattern[row['targetSkeleton']]={}
        pattern[row['targetSkeleton']][row['sourceSkeleton']]={row['Affix']}

# %%
print(pattern)
# Out:
# {'!1!ness': {'#1#': {'ness'}, '#1#e': {'ness'}}, '!1!ly': {'#1#': {'ly', 'y', 'ally'}, '#1#ed': {'ly'}}, '!1!ic': {'#1#e': {'ic'}, '#1#': {'ic'}, '#1#on': {'ic'}, '#1#y': {'ic'}, '#1#ue': {'ic'}, '#1#a': {'ic'}, '#1#en': {'ic'}, '#1#us': {'ic'}, '#1#osis': {'ic'}}, '!1!man': {'#1#': {'man'}}, '!1!er': {'#1#': {'er'}, '#1#y': {'er'}, '#1#ational': {'er'}, '#1#or': {'er'}, '#1#our': {'er'}, 'bal#1#': {'er'}}, '!1!or': {'#1#e': {'or'}, '#1#': {'or'}, '#1#eur': {'or'}}, '!1!al': {'#1#e': {'al'}, '#1#': {'al'}, '#1#us': {'al'}, '#1#um': {'al'}, '#1#is': {'al'}}, '!1!ise': {'#1#': {'ise'}, '#1#us': {'ise'}, '#1#e': {'ise'}}, '!1!ist': {'#1#y': {'ist'}, '#1#': {'ist'}, '#1#e': {'ist'}, '#1#a': {'ist'}, '#1#s': {'ist'}, '#1#o': {'ist'}, '#1#us': {'ist'}}, '!1!r': {'#1#': {'er'}, '#1#s': {'er'}}, '!1!let': {'#1#': {'let'}}, '!1!ily': {'#1#y': {'ly'}}, '!1!mer': {'#1#': {'er'}}, '!1!ize': {'#1#': {'ize'}, '#1#e': {'ize'}, '#1#y': {'ize'}}, '!1!ical': {'#1#': {'ical'}, '#1#y': {'ic', 'ical'}, '#1#e': {'ical'}, '#1#ery': {'ical'}, '#1#ue': {'ical'}}, '!1!ty': {'#1#': {'y'}, '#1#ous': {'ity'}}, '!1!ter': {'#1#': {'er'}}, '!1!ally': {'#1#': {'ly', 'ally'}}, '!1!ment': {'#1#': {'ment'}, '#1#e': {'ment'}, '#1#r': {'ment'}, '#1#l': {'ment'}, '#1#d': {'ment'}}, '!1!l': {'#1#': {'al'}}, '!1!like': {'#1#': {'like'}}, '!1!ous': {'#1#y': {'ous'}, '#1#': {'ous'}, '#1#um': {'ous'}, '#1#a': {'ous'}, '#1#e': {'ous'}}, '!1!y': {'#1#': {'ly', 'y'}, '#1#e': {'ly', 'y'}, '#1#ey': {'ly', 'y'}, '#1#i': {'y'}, '#1#as': {'ity'}, '#1#er': {'y'}, '#1#idextrous': {'y'}}, '!1!ful': {'#1#': {'ful'}, '#1#e': {'ful'}}, '!1!ier': {'#1#y': {'er'}, '#1#e': {'er'}}, '!1!en': {'#1#': {'en'}}, '!1!ility': {'#1#le': {'ity'}}, '!1!iness': {'#1#y': {'ness'}}, '!1!ism': {'#1#': {'ism'}, '#1#a': {'ism'}, '#1#e': {'ism'}, '#1#y': {'ism'}, '#1#ese': {'ism'}}, '!1!sayer': {'#1#': {'er'}}, '!1!ship': {'#1#': {'ship'}}, '!1!ss': {'#1#r': {'ess'}, '#1#': {'ess'}}, '!1!ity': {'#1#e': {'ity'}, '#1#': {'ity'}, '#1#y': {'ity'}}, 'mooey': {'mui': {'y'}}, '!1!oid': {'#1#ia': {'oid'}, '#1#e': {'oid'}, '#1#': {'oid'}, '#1#um': {'oid'}, '#1#ium': {'oid'}, '#1#ic': {'oid'}, '#1#ie': {'oid'}, '#1#i': {'oid'}, '#1#ical': {'oid'}, '#1#us': {'oid'}, '#1#eus': {'oid'}}, '!1!st': {'#1#cs': {'ist'}, '#1#ze': {'ist'}, '#1#': {'ist'}, '#1#ve': {'ist'}, '#1#a': {'ist'}, '#1#c': {'ist'}}, '!1!ress': {'#1#or': {'ess'}, '#1#er': {'ess'}}, '!1!wise': {'#1#': {'wise'}}, '!1!age': {'#1#e': {'age'}, '#1#': {'age'}}, '!1!ee': {'#1#': {'ee'}, '#1#ate': {'ee'}, '#1#or': {'ee'}}, '!1!ation': {'#1#e': {'ation', 'ion'}, '#1#': {'ation'}}, '!1!e': {'#1#': {'ee'}, '#1#r': {'ee'}}, '!1!tist': {'#1#': {'ist'}}, '!1!ette': {'#1#': {'ette'}, '#1#o': {'ette'}}, '!1!tie': {'#1#': {'ie'}}, '!1!ger': {'#1#': {'er'}}, '!1!ish': {'#1#e': {'ish'}, '#1#': {'ish'}}, '!1!ive': {'#1#': {'ive'}, '#1#e': {'ive'}}, '!2!a!1!': {'#2##1#': {'ly', 'er', 'ful'}}, '!1!py': {'#1#': {'y'}, '#1#kin': {'y'}}, '!1!ner': {'#1#': {'er'}}, '!1!nish': {'#1#': {'ish'}}, '!1!hood': {'#1#': {'hood'}}, '!1!t': {'#1#m': {'ist'}, '#1#': {'let'}, '#1#e': {'ist'}, '#1#is': {'ist'}}, '!1!der': {'#1#': {'er'}}, '!1!ling': {'#1#': {'ling'}, '#1#e': {'ling'}}, '!2!u!1!': {'#2##1#': {'ment'}}, '!1!ess': {'#1#': {'ess'}}, '!1!per': {'#1#': {'er'}}, '!1!dy': {'#1#': {'y'}, '#1#i': {'y'}}, '!1!proof': {'#1#': {'proof'}}, '!1!ie': {'#1#': {'ie'}, '#1#e': {'ie'}, '#1#al': {'ie'}, '#1#unist': {'ie'}}, '!1!': {'#1#is': {'al'}, '#1#ho': {'ly'}, '#1#r': {'ise', 'le'}, '#1#e': {'ist', 'ess', 'ism', 'ness'}, '#1#ish': {'er'}, '#1#us': {'ic'}, '#1#m': {'o'}, '#1#tic': {'o'}, '#1#te': {'let'}}, '!1!ber': {'#1#': {'er'}}, '!1!n': {'#1#': {'en', 'ian'}}, '!1!sman': {'#1#': {'man'}}, '!1!do': {'#1#': {'o'}}, 'measly': {'misellus': {'y'}}, '!1!tic': {'#1#sis': {'ic'}, '#1#m': {'ic'}, '#1#s': {'ic'}, '#1#': {'ic'}, '#1#cy': {'ic'}}, '!1!by': {'#1#': {'y'}}, '!1!rist': {'#1#ur': {'ist'}}, '!1!gy': {'#1#': {'y'}, '#1#nore': {'y'}}, '!2!p!1!': {'#2#m#1#': {'le'}}, '!1!ster': {'#1#':  ...

# %%
glovewords={}
with open('glove_word.txt', 'r') as document:
    glovewords = {}
    for line in document:
        line = line.split()
        if not line:  # empty line
            continue
        glovewords[line[0]] = []

# %%
def lcs1(X, Y, m, n): 
    L = [[0 for x in range(n+1)] for x in range(m+1)]   
    for i in range(m+1): 
        for j in range(n+1): 
            if i == 0 or j == 0: 
                L[i][j] = 0
            elif X[i-1] == Y[j-1]: 
                L[i][j] = L[i-1][j-1] + 1
            else: 
                L[i][j] = max(L[i-1][j], L[i][j-1])  
    index = L[m][n]  
    lcs = [""] * (index+1) 
    lcs[index] = "" 
    i = m 
    j = n 
    left=[]
    flag=1
    flag1=0
    right=[]
    while i > 0 and j > 0: 
        #print(X[i-1],' ',Y[j-1])
        if X[i-1] == Y[j-1]: 
            lcs[index-1] = X[i-1] 
            i-=1
            right.extend(Y[j-1])
            j-=1
            index-=1
            if i==0 :
                #print(',')
                left.extend(',')
            flag=0
            flag1=0
        elif L[i-1][j] > L[i][j-1]:
            if flag==0:
                left.extend(',')
                flag=1
            if flag1==0:
                right.extend(',')
                flag1=1
            i-=1
        else:
            if flag==0:
                #print(',')
                left.extend(',')
                flag=1
            if flag1==0:
                right.extend(',')
                flag1=1
            left.extend(Y[j-1])
            j-=1
    while i > 0:
        i-=1
    while j > 0:
        left.extend(Y[j-1])
        j-=1
    string="".join(left)
    string1=string[::-1]
    string5="".join(right)
    string6=string5[::-1]
#     print(string6)
    string2=[]
    i=0
    while i<(len(X)):
        if X[i]=='!':
            if i!=0:
                string2.extend(','+X[i]+X[i+1]+X[i+2])
            else:
                string2.extend(X[i]+X[i+1]+X[i+2])
            i+=3
        else:
            i+=1
    if(X[i-1])!='!':
        string2.extend(',')
    string3="".join(string2)
    return "".join(lcs),string1,string3,string6

# %%
str1='!2!page!4!ion'
str2='agetyuion'
print(lcs1(str1,str2,len(str1),len(str2)))
# Out:
# ('ageion', 'tyu,', '!2!,!4!,', 'age,ion')

# %%
def check(x,y):
    z,w,u,v=lcs1(x,y,len(x),len(y))
    u=u.split(',')
    w=w.split(',')
#     print(u)
#     print(w)
    if(len(w)!=len(u)):
        return -1
    t=[]
    t.append([])
    i=0
    j=0
    while i <len(x):
        if x[i]=='!':
            if(i!=0):
                t[j]="".join(t[j])
            i+=3
            j+=1
            t.append([])
        else:
            t[j].extend(x[i])
            i+=1
    t[j]="".join(t[j])
#     print(t)
    v=v.split(',')
#     print(v)
    i=0
    while i <len(t):
        try:
            if len(t[i])==0 and v[i]!='':
                return -1
            elif  len(t[i])!=0 and v[i]=='':
                return -1
            elif  len(t[i])==0 and v[i]=='':
                i+=1
                continue
            elif t[i]!=v[i]:
                return -1
        except IndexError:
            return -1
        i+=1
    
    i=0
    p=[]
    while i<len(w):
        if w[i]=='' and u[i]!='':
            return -1
        elif w[i]!='' and u[i]=='':
            return -1
        if w[i]=='' and u[i]=='':
            i+=1
            continue
        p.append(w[i])
        i+=1
    
    return p

# %%
check('xy!2!ty!3!ui','xybaatyerui')
# Out:
# ['baa', 'er']

# %%
def add(X,Y):
    i=0 
    j=0
    while i<(len(X)):
        if X[i]=='#':
            i+=3
            j+=1
        else:
            i+=1
    string2=[]
    for i in range(j+1) :
        string2.append([])
#     print(string2)
    i=j=0
    while i<(len(X)):
        if X[i]=='#':
            j+=1
            i+=3
        else:
            string2[j].extend(X[i])
            i+=1
#     print(j)
#     print(len(Y))
    if (j)!=(len(Y)):
        return -1
#     print(string2)
    z=[]
    i=0
    while i < j:
        z.extend(string2[i])
        z.extend(Y[i])
        i+=1
    z.extend(string2[i])
    return "".join(z)

# %%
def transform(x,y):
    X=x[0]
    Y=check(X,y)
    if(Y==-1):
        return -1
#     print(x[0])
#     print(Y)
    z=add(x[1],Y)
    return z

# %%
# a=pattern.pop()
# pattern.add(a)
# print(a)
a=('in#1##2#', 'bo!1!in!2!')
pat=['!1!page','#1#']
string='packpage'
transform(pat,string)
# Out:
# 'pack'

# %%
print(pattern)
# Out:
# {'!1!ness': {'#1#': {'ness'}, '#1#e': {'ness'}}, '!1!ly': {'#1#': {'ly', 'y', 'ally'}, '#1#ed': {'ly'}}, '!1!ic': {'#1#e': {'ic'}, '#1#': {'ic'}, '#1#on': {'ic'}, '#1#y': {'ic'}, '#1#ue': {'ic'}, '#1#a': {'ic'}, '#1#en': {'ic'}, '#1#us': {'ic'}, '#1#osis': {'ic'}}, '!1!man': {'#1#': {'man'}}, '!1!er': {'#1#': {'er'}, '#1#y': {'er'}, '#1#ational': {'er'}, '#1#or': {'er'}, '#1#our': {'er'}, 'bal#1#': {'er'}}, '!1!or': {'#1#e': {'or'}, '#1#': {'or'}, '#1#eur': {'or'}}, '!1!al': {'#1#e': {'al'}, '#1#': {'al'}, '#1#us': {'al'}, '#1#um': {'al'}, '#1#is': {'al'}}, '!1!ise': {'#1#': {'ise'}, '#1#us': {'ise'}, '#1#e': {'ise'}}, '!1!ist': {'#1#y': {'ist'}, '#1#': {'ist'}, '#1#e': {'ist'}, '#1#a': {'ist'}, '#1#s': {'ist'}, '#1#o': {'ist'}, '#1#us': {'ist'}}, '!1!r': {'#1#': {'er'}, '#1#s': {'er'}}, '!1!let': {'#1#': {'let'}}, '!1!ily': {'#1#y': {'ly'}}, '!1!mer': {'#1#': {'er'}}, '!1!ize': {'#1#': {'ize'}, '#1#e': {'ize'}, '#1#y': {'ize'}}, '!1!ical': {'#1#': {'ical'}, '#1#y': {'ic', 'ical'}, '#1#e': {'ical'}, '#1#ery': {'ical'}, '#1#ue': {'ical'}}, '!1!ty': {'#1#': {'y'}, '#1#ous': {'ity'}}, '!1!ter': {'#1#': {'er'}}, '!1!ally': {'#1#': {'ly', 'ally'}}, '!1!ment': {'#1#': {'ment'}, '#1#e': {'ment'}, '#1#r': {'ment'}, '#1#l': {'ment'}, '#1#d': {'ment'}}, '!1!l': {'#1#': {'al'}}, '!1!like': {'#1#': {'like'}}, '!1!ous': {'#1#y': {'ous'}, '#1#': {'ous'}, '#1#um': {'ous'}, '#1#a': {'ous'}, '#1#e': {'ous'}}, '!1!y': {'#1#': {'ly', 'y'}, '#1#e': {'ly', 'y'}, '#1#ey': {'ly', 'y'}, '#1#i': {'y'}, '#1#as': {'ity'}, '#1#er': {'y'}, '#1#idextrous': {'y'}}, '!1!ful': {'#1#': {'ful'}, '#1#e': {'ful'}}, '!1!ier': {'#1#y': {'er'}, '#1#e': {'er'}}, '!1!en': {'#1#': {'en'}}, '!1!ility': {'#1#le': {'ity'}}, '!1!iness': {'#1#y': {'ness'}}, '!1!ism': {'#1#': {'ism'}, '#1#a': {'ism'}, '#1#e': {'ism'}, '#1#y': {'ism'}, '#1#ese': {'ism'}}, '!1!sayer': {'#1#': {'er'}}, '!1!ship': {'#1#': {'ship'}}, '!1!ss': {'#1#r': {'ess'}, '#1#': {'ess'}}, '!1!ity': {'#1#e': {'ity'}, '#1#': {'ity'}, '#1#y': {'ity'}}, 'mooey': {'mui': {'y'}}, '!1!oid': {'#1#ia': {'oid'}, '#1#e': {'oid'}, '#1#': {'oid'}, '#1#um': {'oid'}, '#1#ium': {'oid'}, '#1#ic': {'oid'}, '#1#ie': {'oid'}, '#1#i': {'oid'}, '#1#ical': {'oid'}, '#1#us': {'oid'}, '#1#eus': {'oid'}}, '!1!st': {'#1#cs': {'ist'}, '#1#ze': {'ist'}, '#1#': {'ist'}, '#1#ve': {'ist'}, '#1#a': {'ist'}, '#1#c': {'ist'}}, '!1!ress': {'#1#or': {'ess'}, '#1#er': {'ess'}}, '!1!wise': {'#1#': {'wise'}}, '!1!age': {'#1#e': {'age'}, '#1#': {'age'}}, '!1!ee': {'#1#': {'ee'}, '#1#ate': {'ee'}, '#1#or': {'ee'}}, '!1!ation': {'#1#e': {'ation', 'ion'}, '#1#': {'ation'}}, '!1!e': {'#1#': {'ee'}, '#1#r': {'ee'}}, '!1!tist': {'#1#': {'ist'}}, '!1!ette': {'#1#': {'ette'}, '#1#o': {'ette'}}, '!1!tie': {'#1#': {'ie'}}, '!1!ger': {'#1#': {'er'}}, '!1!ish': {'#1#e': {'ish'}, '#1#': {'ish'}}, '!1!ive': {'#1#': {'ive'}, '#1#e': {'ive'}}, '!2!a!1!': {'#2##1#': {'ly', 'er', 'ful'}}, '!1!py': {'#1#': {'y'}, '#1#kin': {'y'}}, '!1!ner': {'#1#': {'er'}}, '!1!nish': {'#1#': {'ish'}}, '!1!hood': {'#1#': {'hood'}}, '!1!t': {'#1#m': {'ist'}, '#1#': {'let'}, '#1#e': {'ist'}, '#1#is': {'ist'}}, '!1!der': {'#1#': {'er'}}, '!1!ling': {'#1#': {'ling'}, '#1#e': {'ling'}}, '!2!u!1!': {'#2##1#': {'ment'}}, '!1!ess': {'#1#': {'ess'}}, '!1!per': {'#1#': {'er'}}, '!1!dy': {'#1#': {'y'}, '#1#i': {'y'}}, '!1!proof': {'#1#': {'proof'}}, '!1!ie': {'#1#': {'ie'}, '#1#e': {'ie'}, '#1#al': {'ie'}, '#1#unist': {'ie'}}, '!1!': {'#1#is': {'al'}, '#1#ho': {'ly'}, '#1#r': {'ise', 'le'}, '#1#e': {'ist', 'ess', 'ism', 'ness'}, '#1#ish': {'er'}, '#1#us': {'ic'}, '#1#m': {'o'}, '#1#tic': {'o'}, '#1#te': {'let'}}, '!1!ber': {'#1#': {'er'}}, '!1!n': {'#1#': {'en', 'ian'}}, '!1!sman': {'#1#': {'man'}}, '!1!do': {'#1#': {'o'}}, 'measly': {'misellus': {'y'}}, '!1!tic': {'#1#sis': {'ic'}, '#1#m': {'ic'}, '#1#s': {'ic'}, '#1#': {'ic'}, '#1#cy': {'ic'}}, '!1!by': {'#1#': {'y'}}, '!1!rist': {'#1#ur': {'ist'}}, '!1!gy': {'#1#': {'y'}, '#1#nore': {'y'}}, '!2!p!1!': {'#2#m#1#': {'le'}}, '!1!ster': {'#1#':  ...

# %%
import csv
data=[['dfcg','qqppp'],['dfcg','qqppp'],['dfcg','qqppp']]
file_path='false_pairs.csv'
# with open('false_pairs.csv', "wb") as csv_file:
#     writer = csv.writer(csv_file, delimiter=',')
#     for line in data:
#         writer.writerows(line)
# import csv
with open(file_path, 'a') as outcsv:   
    #configure writer to write standard csv file
    writer = csv.writer(outcsv, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL, lineterminator='\n')
    writer.writerow(['number', 'text'])
    for item in data:
        #Write item to outcsv
        writer.writerow([item[0], item[1]])

# %%
# i=0
import csv
ile_path='false_pairs.csv'
i=0
with open(file_path, 'a') as outcsv:   
    writer = csv.writer(outcsv, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL, lineterminator='\n')
    writer.writerow(['Affix', 'Source word', 'Derived word','sourceSkeleton','targetSkeleton'])
    for p, value in pattern.items():
#         if(i==40):
#             break
        for q, affixset in value.items():
            pat=[p,q]
            i=0
            print('\n\n')
            print(pat[0])
            print(pat[1])
            print('\n\n')
            for der in glovewords:
                if(i>2000):
                    break
        #         print(der,end='\t')
                a=transform(pat,der)
        #         print(a)
                if a==-1:
                    continue
                try:
                    i+=1
                    glovewords[a]
                    for val in affixset: 
                        writer.writerow([val,a,der,pat[1],pat[0]])
                        print(val,end='\t')
                        print(a,end='\t')
                        print(der,end='\t')
                        print(pat[1],end='\t')
                        print(pat[0])
                except KeyError:
                    pass
# Out:
# !1!ness
# #1#
#
#
#
# ness	busi	business	#1#	!1!ness
# ness	Busi	Business	#1#	!1!ness
# ness	fit	fitness	#1#	!1!ness
# ness	aware	awareness	#1#	!1!ness
# ness	Fit	Fitness	#1#	!1!ness
# ness	ill	illness	#1#	!1!ness
# ness	happi	happiness	#1#	!1!ness
# ness	wit	witness	#1#	!1!ness
# ness	effective	effectiveness	#1#	!1!ness
# ness	dark	darkness	#1#	!1!ness
# ness	good	goodness	#1#	!1!ness
# ness	conscious	consciousness	#1#	!1!ness
# ness	thick	thickness	#1#	!1!ness
# ness	weak	weakness	#1#	!1!ness
# ness	Well	Wellness	#1#	!1!ness
# ness	Aware	Awareness	#1#	!1!ness
# ness	well	wellness	#1#	!1!ness
# ness	har	harness	#1#	!1!ness
# ness	wilder	wilderness	#1#	!1!ness
# ness	willing	willingness	#1#	!1!ness
# ness	Dark	Darkness	#1#	!1!ness
# ness	kind	kindness	#1#	!1!ness
# ness	forgive	forgiveness	#1#	!1!ness
# ness	Mad	Madness	#1#	!1!ness
# ness	mad	madness	#1#	!1!ness
# ness	Happi	Happiness	#1#	!1!ness
# ness	sick	sickness	#1#	!1!ness
# ness	bright	brightness	#1#	!1!ness
# ness	sad	sadness	#1#	!1!ness
# ness	Wilder	Wilderness	#1#	!1!ness
# ness	fair	fairness	#1#	!1!ness
# ness	righteous	righteousness	#1#	!1!ness
# ness	Wit	Witness	#1#	!1!ness
# ness	sweet	sweetness	#1#	!1!ness
# ness	great	greatness	#1#	!1!ness
# ness	Guin	Guinness	#1#	!1!ness
# ness	Har	Harness	#1#	!1!ness
# ness	bitter	bitterness	#1#	!1!ness
# ness	readi	readiness	#1#	!1!ness
# ness	useful	usefulness	#1#	!1!ness
# ness	competitive	competitiveness	#1#	!1!ness
# ness	open	openness	#1#	!1!ness
# ness	serious	seriousness	#1#	!1!ness
# ness	rich	richness	#1#	!1!ness
# ness	stiff	stiffness	#1#	!1!ness
# ness	Conscious	Consciousness	#1#	!1!ness
# ness	blind	blindness	#1#	!1!ness
# ness	fresh	freshness	#1#	!1!ness
# ness	dizzi	dizziness	#1#	!1!ness
# ness	unique	uniqueness	#1#	!1!ness
# ness	correct	correctness	#1#	!1!ness
# ness	Ill	Illness	#1#	!1!ness
# ness	hard	hardness	#1#	!1!ness
# ness	complete	completeness	#1#	!1!ness
# ness	prepared	preparedness	#1#	!1!ness
# ness	Effective	Effectiveness	#1#	!1!ness
# ness	full	fullness	#1#	!1!ness
# ness	holi	holiness	#1#	!1!ness
# ness	like	likeness	#1#	!1!ness
# ness	Thick	Thickness	#1#	!1!ness
# ness	soft	softness	#1#	!1!ness
# ness	Inver	Inverness	#1#	!1!ness
# ness	red	redness	#1#	!1!ness
# ness	tender	tenderness	#1#	!1!ness
# ness	homeless	homelessness	#1#	!1!ness
# ness	Good	Goodness	#1#	!1!ness
# ness	awesome	awesomeness	#1#	!1!ness
# ness	tough	toughness	#1#	!1!ness
# ness	numb	numbness	#1#	!1!ness
# ness	responsive	responsiveness	#1#	!1!ness
# ness	sharp	sharpness	#1#	!1!ness
# ness	Prepared	Preparedness	#1#	!1!ness
# ness	lazi	laziness	#1#	!1!ness
# ness	dry	dryness	#1#	!1!ness
# ness	Forgive	Forgiveness	#1#	!1!ness
# ness	Holi	Holiness	#1#	!1!ness
# ness	selfish	selfishness	#1#	!1!ness
# ness	faithful	faithfulness	#1#	!1!ness
# ness	sore	soreness	#1#	!1!ness
# ness	crazi	craziness	#1#	!1!ness
# ness	attractive	attractiveness	#1#	!1!ness
# ness	nervous	nervousness	#1#	!1!ness
# ness	tight	tightness	#1#	!1!ness
# ness	fond	fondness	#1#	!1!ness
# ness	close	closeness	#1#	!1!ness
# ness	wicked	wickedness	#1#	!1!ness
# ness	random	randomness	#1#	!1!ness
# ness	Kind	Kindness	#1#	!1!ness
# ness	Readi	Readiness	#1#	!1!ness
# ness	smooth	smoothness	#1#	!1!ness
# ness	Fair	Fairness	#1#	!1!ness
# ness	appropriate	appropriateness	#1#	!1!ness
# ness	mindful	mindfulness	#1#	!1!ness
# ness	still	stillness	#1#	!1!ness
# ness	short	shortness	#1#	!1!ness
# ness	bald	baldness	#1#	!1!ness
# ness	tired	tiredness	#1#	!1!ness
# ness	foolish	foolishness	#1#	!1!ness
# ness	firm	firmness	#1#	!1!ness
# ness	cool	coolness	#1#	!1!ness
# ness	light	lightness	#1#	!1!ness
# ness	unwilling	unwillingness	#1#	!1!ness
# ness	cute	cuteness	#1#	!1!ness
# ness	quick	quickness	#1#	!1!ness
# ness	silli	silliness	#1#	!1!ness
# ness	eager	eagerness	#1#	!1!ness
# ness	Bright	Brightness	#1#	!1!ness
# ness	Baro	Baroness	#1#	!1!ness
# ness	Sick	Sickness	#1#	!1!ness
# ness	indebted	indebtedness	#1#	!1!ness
# ness	High	Highness	#1#	!1!ness
# ness	weird	weirdness	#1#	!1!ness
# ness	Weak	Weakness	#1#	!1!ness
# ness	hopeless	hopelessness	#1#	!1!ness
# ness	robust	robustness	#1#	!1!ness
# ness	bold	boldness	#1#	!1!ness
# ness	one	oneness	#1#	!1!ness
# ness	gentle	gentleness	#1#	!1!ness
# ness	shy	shyness	#1#	!1!ness
# ness	self-aware	self-awareness	#1#	!1!ness
# ness	whole	wholeness	#1#	!1!ness
# ness	rough	roughness	#1#	!1!ness
# ness	helpless	helplessness	#1#	!1!ness
# ness	nothing	nothingness	#1#	!1!ness
# ness	alert	alertness	#1#	!1!ness
# ness	Preak	Preakness	#1#	!1!ness
# ness	calm	calmness	#1#	!1!ness
# ness	black	blackness	#1#	!1!ness
# ness	buis	buisness	#1#	!1!ness
# ness	restless	restlessness	#1#	!1!ness
# ness	Sad	Sadness	#1#	!1!ness
# ness	awkward	awkwardness	#1#	!1!ness
# ness	Homeless	Homelessness	#1#	!1!ness
# ness	ugli	ugliness	#1#	!1!ness
# ness	Mindful	Mindfulness	#1#	!1!ness
# ness	Great	Greatness	#1#	!1!ness
# ness	wet	wetness	#1#	!1!ness
# ness	aggressive	aggressiveness	#1#	!1!ness
# ness	Competitive	Competitiveness	#1#	!1!ness
# ness	worthi	worthiness	#1#	!1!ness
# ness	careless	carelessness	#1#	!1!ness
# ness	deaf	deafness	#1#	!1!ness
# ness	cost-effective	cost-effectiveness	#1#	!1!ness
# ness	heavi	heaviness	#1#	!1!ness
# ness	hot	hotness	#1#	!1!ness
# ness	together	togetherness	#1#	!1!ness
# ness	Hot	Hotness	#1#	!1!ness
# ness	sound	soundness	#1#	!1!ness
# ness	polite	politeness	#1#	!1!ness
# ness	new	newness	#1#	!1!ness
# ness	rude	rudeness	#1#	!1!ness
# ness	drunken	drunkenness	#1#	!1!ness
# ness	white	whiteness	#1#	!1!ness
# ness	Blind	Blindness	#1#	!1!ness
# ness	sleepi	sleepiness	#1#	!1!ness
# ness	lawless	lawlessness	#1#	!1!ness
# ness	truthful	truthfulness	#1#	!1!ness
# ness	thoughtful	thoughtfulness	#1#	!1!ness
# ness	One	Oneness	#1#	!1!ness
# ness	cold	coldness	#1#	!1!ness
# ness	playful	playfulness	#1#	!1!ness
# ness	McGuin	McGuinness	#1#	!1!ness
# ness	vast	vastness	#1#	!1!ness
# ness	Random	Randomness	#1#	!1!ness
# ness	reasonable	reasonableness	#1#	!1!ness
# ness	helpful	helpfulness	#1#	!1!ness
# ness	naked	nakedness	#1#	!1!ness
# ness	harsh	harshness	#1#	!1!ness
# ness	clever	cleverness	#1#	!1!ness
# ness	loud	loudness	#1#	!1!ness
# ness	unfair	unfairness	#1#	!1!ness
# ness	slow	slowness	#1#	!1!ness
# ness	glad	gladness	#1#	!1!ness
# ness	Skeg	Skegness	#1#	!1!ness
# ness	unconscious	unconsciousness	#1#	!1!ness
# ness	sexi	sexiness	#1#	!1!ness
# ness	quiet	quietness	#1#	!1!ness
# ness	Sweet	Sweetness	#1#	!1!ness
# ness	stubborn	stubbornness	#1#	!1!ness
# ness	loveli	loveliness	#1#	!1!ness
# ness	strange	strangeness	#1#	!1!ness
# ness	Awesome	Awesomeness	#1#	!1!ness
# ness	Righteous	Righteousness	#1#	!1!ness
# ness	weari	weariness	#1#	!1!ness
# ness	damp	dampness	#1#	!1!ness
# ness	forgetful	forgetfulness	#1#	!1!ness
# ness	clear	clearness	#1#	!1!ness
# ness	connected	connectedness	#1#	!1!ness
# ness	nasti	nastiness	#1#	!1!ness
# ness	Hard	Hardness	#1#	!1!ness
# ness	Fur	Furness	#1#	!1!ness
# ness	resourceful	resourcefulness	#1#	!1!ness
# ness	Open	Openness	#1#	!1!ness
# ness	reckless	recklessness	#1#	!1!ness
# ness	delicious	deliciousness	#1#	!1!ness
# ness	bad	badness	#1#	!1!ness
# ness	thankful	thankfulness	#1#	!1!ness
# ness	sleepless	sleeplessness	#1#	!1!ness
# ness	puffi	puffiness	#1#	!1!ness
# ness	inventive	inventiveness	#1#	!1!ness
# ness	Helpful	Helpfulness	#1#	!1!ness
# ness	Hark	Harkness	#1#	!1!ness
# ness	peaceful	peacefulness	#1#	!1!ness
# ness	thorough	thoroughness	#1#	!1!ness
# ness	earnest	earnestness	#1#	!1!ness
# ness	selfless	selflessness	#1#	!1!ness
# ness	vague	vagueness	#1#	!1!ness
# ness	flat	flatness	#1#	!1!ness
# ness	lame	lameness	#1#	!1!ness
# ness	ridiculous	ridiculousness	#1#	!1!ness
# ness	self-conscious	self-consciousness	#1#	!1!ness
# ness	Gui	Guiness	#1#	!1!ness
# ness	same	sameness	#1#	!1!ness
# ness	Dizzi	Dizziness	#1#	!1!ness
# ness	inclusive	inclusiveness	#1#	!1!ness
# ness	powerless	powerlessness	#1#	!1!ness
# ness	assertive	assertiveness	#1#	!1!ness
# ness	Willing	Willingness	#1#	!1!ness
# ness	ful	fulness	#1#	!1!ness
# ness	Caith	Caithness	#1#	!1!ness
# ness	broken	brokenness	#1#	!1!ness
# ness	unrighteous	unrighteousness	#1#	!1!ness
# ness	ineffective	ineffectiveness	#1#	!1!ness
# ness	idle	idleness	#1#	!1!ness
# ness	wild	wildness	#1#	!1!ness
# ness	crisp	crispness	#1#	!1!ness
# ness	interconnected	interconnectedness	#1#	!1!ness
# ness	Fresh	Freshness	#1#	!1!ness
# ness	busy	busyness	#1#	!1!ness
# ness	distinctive	distinctiveness	#1#	!1!ness
# ness	attentive	attentiveness	#1#	!1!ness
# ness	Correct	Correctness	#1#	!1!ness
# ness	tart	tartness	#1#	!1!ness
# ness	Dunge	Dungeness	#1#	!1!ness
# ness	remote	remoteness	#1#	!1!ness
# ness	lio	lioness	#1#	!1!ness
# ness	genuine	genuineness	#1#	!1!ness
# ness	gover	governess	#1#	!1!ness
# ness	done	doneness	#1#	!1!ness
# ness	sinful	sinfulness	#1#	!1!ness
# ness	cheerful	cheerfulness	#1#	!1!ness
# ness	dull	dullness	#1#	!1!ness
# ness	Lio	Lioness	#1#	!1!ness
# ness	cohesive	cohesiveness	#1#	!1!ness
# ness	Responsive	Responsiveness	#1#	!1!ness
# ness	compact	compactness	#1#	!1!ness
# ness	thin	thinness	#1#	!1!ness
# ness	ripe	ripeness	#1#	!1!ness
# ness	self-righteous	self-righteousness	#1#	!1!ness
# ness	itchi	itchiness	#1#	!1!ness
# ness	meek	meekness	#1#	!1!ness
# ness	spacious	spaciousness	#1#	!1!ness
# ness	sacred	sacredness	#1#	!1!ness
# ness	jobless	joblessness	#1#	!1!ness
# ness	unpleasant	unpleasantness	#1#	!1!ness
# ness	mean	meanness	#1#	!1!ness
# ness	right	rightness	#1#	!1!ness
# ness	hardi	hardiness	#1#	!1!ness
# ness	late	lateness	#1#	!1!ness
# ness	direct	directness	#1#	!1!ness
# ness	Tough	Toughness	#1#	!1!ness
# ness	fine	fineness	#1#	!1!ness
# ness	near	nearness	#1#	!1!ness
# ness	frank	frankness	#1#	!1!ness
# ness	tardi	tardiness	#1#	!1!ness
# ness	Tender	Tenderness	#1#	!1!ness
# ness	supple	suppleness	#1#	!1!ness
# ness	cozi	coziness	#1#	!1!ness
# ness	rugged	ruggedness	#1#	!1!ness
# ness	fearless	fearlessness	#1#	!1!ness
# ness	incomplete	incompleteness	#1#	!1!ness
# ness	swift	swiftness	#1#	!1!ness
# ness	Deaf	Deafness	#1#	!1!ness
# ness	timeless	timelessness	#1#	!1!ness
# ness	sour	sourness	#1#	!1!ness
# ness	expressive	expressiveness	#1#	!1!ness
# ness	round	roundness	#1#	!1!ness
# ness	wakeful	wakefulness	#1#	!1!ness
# ness	fat	fatness	#1#	!1!ness
# ness	lightheaded	lightheadedness	#1#	!1!ness
# ness	ruthless	ruthlessness	#1#	!1!ness
# ness	neat	neatness	#1#	!1!ness
# ness	high	highness	#1#	!1!ness
# ness	fruiti	fruitiness	#1#	!1!ness
# ness	Still	Stillness	#1#	!1!ness
# ness	guin	guinness	#1#	!1!ness
# ness	homesick	homesickness	#1#	!1!ness
# ness	Bald	Baldness	#1#	!1!ness
# ness	covetous	covetousness	#1#	!1!ness
# ness	gracious	graciousness	#1#	!1!ness
# ness	creative	creativeness	#1#	!1!ness
# ness	Unique	Uniqueness	#1#	!1!ness
# ness	explosive	explosiveness	#1#	!1!ness
# ness	steadfast	steadfastness	#1#	!1!ness
# ness	defensive	defensiveness	#1#	!1!ness
# ness	Red	Redness	#1#	!1!ness
# ness	grateful	gratefulness	#1#	!1!ness
# ness	current	currentness	#1#	!1!ness
# ness	raw	rawness	#1#	!1!ness
# ness	other	otherness	#1#	!1!ness
# ness	anxious	anxiousness	#1#	!1!ness
# ness	Useful	Usefulness	#1#	!1!ness
# ness	salti	saltiness	#1#	!1!ness
# ness	Cute	Cuteness	#1#	!1!ness
# ness	small	smallness	#1#	!1!ness
# ness	divisive	divisiveness	#1#	!1!ness
# ness	loose	looseness	#1#	!1!ness
# ness	Shadow	Shadowness	#1#	!1!ness
# ness	gay	gayness	#1#	!1!ness
# ness	useless	uselessness	#1#	!1!ness
# ness	unclean	uncleanness	#1#	!1!ness
# ness	minded	mindedness	#1#	!1!ness
# ness	Light	Lightness	#1#	!1!ness
# ness	Sharp	Sharpness	#1#	!1!ness
# ness	Faithful	Faithfulness	#1#	!1!ness
# ness	blessed	blessedness	#1#	!1!ness
# ness	epic	epicness	#1#	!1!ness
# ness	smug	smugness	#1#	!1!ness
# ness	related	relatedness	#1#	!1!ness
# ness	vivid	vividness	#1#	!1!ness
# ness	sluggish	sluggishness	#1#	!1!ness
# ness	natural	naturalness	#1#	!1!ness
# ness	prompt	promptness	#1#	!1!ness
# ness	youthful	youthfulness	#1#	!1!ness
# ness	Bitter	Bitterness	#1#	!1!ness
# ness	worthless	worthlessness	#1#	!1!ness
# ness	backward	backwardness	#1#	!1!ness
# ness	Loud	Loudness	#1#	!1!ness
# ness	Short	Shortness	#1#	!1!ness
# ness	healthi	healthiness	#1#	!1!ness
# ness	petti	pettiness	#1#	!1!ness
# ness	Jewish	Jewishness	#1#	!1!ness
# ness	Black	Blackness	#1#	!1!ness
# ness	real	realness	#1#	!1!ness
# ness	shallow	shallowness	#1#	!1!ness
# ness	Complete	Completeness	#1#	!1!ness
# ness	comprehensive	comprehensiveness	#1#	!1!ness
# ness	fierce	fierceness	#1#	!1!ness
# ness	Numb	Numbness	#1#	!1!ness
# ness	fast	fastness	#1#	!1!ness
# ness	cheap	cheapness	#1#	!1!ness
# ness	Stiff	Stiffness	#1#	!1!ness
# ness	Lazi	Laziness	#1#	!1!ness
# ness	easi	easiness	#1#	!1!ness
# ness	exact	exactness	#1#	!1!ness
# ness	Whole	Wholeness	#1#	!1!ness
# ness	uneven	unevenness	#1#	!1!ness
# ness	vicious	viciousness	#1#	!1!ness
# ness	breathless	breathlessness	#1#	!1!ness
# ness	cosi	cosiness	#1#	!1!ness
# ness	Hardi	Hardiness	#1#	!1!ness
# ness	hoarse	hoarseness	#1#	!1!ness
# ness	nice	niceness	#1#	!1!ness
# ness	weightless	weightlessness	#1#	!1!ness
# ness	keen	keenness	#1#	!1!ness
# ness	obvious	obviousness	#1#	!1!ness
# ness	awful	awfulness	#1#	!1!ness
# ness	Crazi	Craziness	#1#	!1!ness
# ness	open-minded	open-mindedness	#1#	!1!ness
# ness	purposeful	purposefulness	#1#	!1!ness
# ness	narrow	narrowness	#1#	!1!ness
# ness	single	singleness	#1#	!1!ness
# ness	Cool	Coolness	#1#	!1!ness
# ness	callous	callousness	#1#	!1!ness
# ness	Shy	Shyness	#1#	!1!ness
# ness	wrong	wrongness	#1#	!1!ness
# ness	messi	messiness	#1#	!1!ness
# ness	concious	conciousness	#1#	!1!ness
# ness	wari	wariness	#1#	!1!ness
# ness	gifted	giftedness	#1#	!1!ness
# ness	strict	strictness	#1#	!1!ness
# ness	smoki	smokiness	#1#	!1!ness
# ness	Weird	Weirdness	#1#	!1!ness
# ness	pervasive	pervasiveness	#1#	!1!ness
# ness	Holder	Holderness	#1#	!1!ness
# ness	nearsighted	nearsightedness	#1#	!1!ness
# ness	Bow	Bowness	#1#	!1!ness
# ness	Nothing	Nothingness	#1#	!1!ness
# ness	fruitful	fruitfulness	#1#	!1!ness
# ness	humble	humbleness	#1#	!1!ness
# ness	wretched	wretchedness	#1#	!1!ness
# ness	Selfish	Selfishness	#1#	!1!ness
# ness	separate	separateness	#1#	!1!ness
# ness	human	humanness	#1#	!1!ness
# ness	shaki	shakiness	#1#	!1!ness
# ness	pretti	prettiness	#1#	!1!ness
# ness	Rough	Roughness	#1#	!1!ness
# ness	unfaithful	unfaithfulness	#1#	!1!ness
# ness	Full	Fullness	#1#	!1!ness
# ness	sporti	sportiness	#1#	!1!ness
# ness	fuzzi	fuzziness	#1#	!1!ness
# ness	White	Whiteness	#1#	!1!ness
# ness	Buis	Buisness	#1#	!1!ness
# ness	handed	handedness	#1#	!1!ness
# ness	meaningless	meaninglessness	#1#	!1!ness
# ness	upright	uprightness	#1#	!1!ness
# ness	bland	blandness	#1#	!1!ness
# ness	straight	straightness	#1#	!1!ness
# ness	destructive	destructiveness	#1#	!1!ness
# ness	alive	aliveness	#1#	!1!ness
# ness	steep	steepness	#1#	!1!ness
# ness	hopeful	hopefulness	#1#	!1!ness
# ness	sudden	suddenness	#1#	!1!ness
# ness	gorgeous	gorgeousness	#1#	!1!ness
# ness	inver	inverness	#1#	!1!ness
# ness	Happy	Happyness	#1#	!1!ness
# ness	impulsive	impulsiveness	#1#	!1!ness
# ness	green	greenness	#1#	!1!ness
# ness	decisive	decisiveness	#1#	!1!ness
# ness	evil	evilness	#1#	!1!ness
# ness	Robust	Robustness	#1#	!1!ness
# ness	deep	deepness	#1#	!1!ness
# ness	malti	maltiness	#1#	!1!ness
# ness	bleak	bleakness	#1#	!1!ness
# ness	indecisive	indecisiveness	#1#	!1!ness
# ness	adept	adeptness	#1#	!1!ness
# ness	Bussi	Bussiness	#1#	!1!ness
# ness	lewd	lewdness	#1#	!1!ness
# ness	aloof	aloofness	#1#	!1!ness
# ness	stream-of-conscious	stream-of-consciousness	#1#	!1!ness
# ness	farsighted	farsightedness	#1#	!1!ness
# ness	smart	smartness	#1#	!1!ness
# ness	odd	oddness	#1#	!1!ness
# ness	clueless	cluelessness	#1#	!1!ness
# ness	amazing	amazingness	#1#	!1!ness
# ness	Mag	Magness	#1#	!1!ness
# ness	precious	preciousness	#1#	!1!ness
# ness	Sheer	Sheerness	#1#	!1!ness
# ness	Agy	Agyness	#1#	!1!ness
# ness	Biz	Bizness	#1#	!1!ness
# ness	pretentious	pretentiousness	#1#	!1!ness
# ness	Attractive	Attractiveness	#1#	!1!ness
# ness	clean	cleanness	#1#	!1!ness
# ness	lawful	lawfulness	#1#	!1!ness
# ness	Together	Togetherness	#1#	!1!ness
# ness	blunt	bluntness	#1#	!1!ness
# ness	coarse	coarseness	#1#	!1!ness
# ness	even	evenness	#1#	!1!ness
# ness	seasick	seasickness	#1#	!1!ness
# ness	inept	ineptness	#1#	!1!ness
# ness	Like	Likeness	#1#	!1!ness
# ness	Assertive	Assertiveness	#1#	!1!ness
# ness	Soft	Softness	#1#	!1!ness
# ness	Silli	Silliness	#1#	!1!ness
# ness	pleasant	pleasantness	#1#	!1!ness
# ness	Thankful	Thankfulness	#1#	!1!ness
# ness	self-centered	self-centeredness	#1#	!1!ness
# ness	big	bigness	#1#	!1!ness
# ness	concise	conciseness	#1#	!1!ness
# ness	seductive	seductiveness	#1#	!1!ness
# ness	Dry	Dryness	#1#	!1!ness
# ness	unselfish	unselfishness	#1#	!1!ness
# ness	Sore	Soreness	#1#	!1!ness
# ness	mild	mildness	#1#	!1!ness
# ness	fabulous	fabulousness	#1#	!1!ness
# ness	gui	guiness	#1#	!1!ness
# ness	shrewd	shrewdness	#1#	!1!ness
# ness	yummi	yumminess	#1#	!1!ness
# ness	special	specialness	#1#	!1!ness
# ness	exclusive	exclusiveness	#1#	!1!ness
# ness	wonderful	wonderfulness	#1#	!1!ness
# ness	unaware	unawareness	#1#	!1!ness
# ness	alone	aloneness	#1#	!1!ness
# ness	Serious	Seriousness	#1#	!1!ness
# ness	childish	childishness	#1#	!1!ness
# ness	Indebted	Indebtedness	#1#	!1!ness
# ness	brittle	brittleness	#1#	!1!ness
# ness	male	maleness	#1#	!1!ness
# ness	happy	happyness	#1#	!1!ness
# ness	conscientious	conscientiousness	#1#	!1!ness
# ness	watchful	watchfulness	#1#	!1!ness
# ness	hollow	hollowness	#1#	!1!ness
# ness	vindictive	vindictiveness	#1#	!1!ness
# ness	invasive	invasiveness	#1#	!1!ness
# ness	Foolish	Foolishness	#1#	!1!ness
# ness	slick	slickness	#1#	!1!ness
# ness	stuffi	stuffiness	#1#	!1!ness
# ness	rash	rashness	#1#	!1!ness
# ness	moist	moistness	#1#	!1!ness
# ness	possessive	possessiveness	#1#	!1!ness
# ness	barren	barrenness	#1#	!1!ness
# ness	British	Britishness	#1#	!1!ness
# ness	Nervous	Nervousness	#1#	!1!ness
# ness	faint	faintness	#1#	!1!ness
# ness	Manli	Manliness	#1#	!1!ness
# ness	lush	lushness	#1#	!1!ness
# ness	Tired	Tiredness	#1#	!1!ness
# ness	warm	warmness	#1#	!1!ness
# ness	pointless	pointlessness	#1#	!1!ness
# ness	licentious	licentiousness	#1#	!1!ness
# ness	distinct	distinctness	#1#	!1!ness
# ness	Cost-effective	Cost-effectiveness	#1#	!1!ness
# ness	incorrect	incorrectness	#1#	!1!ness
# ness	persuasive	persuasiveness	#1#	!1!ness
# ness	pale	paleness	#1#	!1!ness
# ness	Bur	Burness	#1#	!1!ness
# ness	dim	dimness	#1#	!1!ness
# ness	patro	patroness	#1#	!1!ness
# ness	sensitive	sensitiveness	#1#	!1!ness
# ness	inquisitive	inquisitiveness	#1#	!1!ness
# ness	elusive	elusiveness	#1#	!1!ness
# ness	wholesome	wholesomeness	#1#	!1!ness
# ness	fearful	fearfulness	#1#	!1!ness
# ness	being	beingness	#1#	!1!ness
# ness	willful	willfulness	#1#	!1!ness
# ness	dangerous	dangerousness	#1#	!1!ness
# ness	repetitive	repetitiveness	#1#	!1!ness
# ness	casual	casualness	#1#	!1!ness
# ness	Quick	Quickness	#1#	!1!ness
# ness	meaningful	meaningfulness	#1#	!1!ness
# ness	gross	grossness	#1#	!1!ness
# ness	large	largeness	#1#	!1!ness
# ness	stale	staleness	#1#	!1!ness
# ness	Polite	Politeness	#1#	!1!ness
# ness	Appropriate	Appropriateness	#1#	!1!ness
# ness	baro	baroness	#1#	!1!ness
# ness	adorable	adorableness	#1#	!1!ness
# ness	acute	acuteness	#1#	!1!ness
# ness	Gover	Governess	#1#	!1!ness
# ness	kind-hearted	kind-heartedness	#1#	!1!ness
# ness	careful	carefulness	#1#	!1!ness
# ness	rebellious	rebelliousness	#1#	!1!ness
# ness	productive	productiveness	#1#	!1!ness
# ness	Helpless	Helplessness	#1#	!1!ness
# ness	Bold	Boldness	#1#	!1!ness
# ness	#fit	#fitness	#1#	!1!ness
# ness	Firm	Firmness	#1#	!1!ness
# ness	short-sighted	short-sightedness	#1#	!1!ness
# ness	ope	openess	#1#	!1!ness
# ness	wasteful	wastefulness	#1#	!1!ness
# ness	shortsighted	shortsightedness	#1#	!1!ness
# ness	forceful	forcefulness	#1#	!1!ness
# ness	innovative	innovativeness	#1#	!1!ness
# ness	stylish	stylishness	#1#	!1!ness
# ness	horni	horniness	#1#	!1!ness
# ness	Ma	Maness	#1#	!1!ness
# ness	inappropriate	inappropriateness	#1#	!1!ness
# ness	dumb	dumbness	#1#	!1!ness
# ness	English	Englishness	#1#	!1!ness
# ness	submissive	submissiveness	#1#	!1!ness
# ness	protective	protectiveness	#1#	!1!ness
# ness	false	falseness	#1#	!1!ness
# ness	healthful	healthfulness	#1#	!1!ness
# ness	Rich	Richness	#1#	!1!ness
# ness	deceitful	deceitfulness	#1#	!1!ness
# ness	active	activeness	#1#	!1!ness
# ness	thoughtless	thoughtlessness	#1#	!1!ness
# ness	Drunken	Drunkenness	#1#	!1!ness
# ness	Alert	Alertness	#1#	!1!ness
# ness	receptive	receptiveness	#1#	!1!ness
# ness	permissive	permissiveness	#1#	!1!ness
# ness	slack	slackness	#1#	!1!ness
# ness	unfit	unfitness	#1#	!1!ness
# ness	usi	usiness	#1#	!1!ness
# ness	pure	pureness	#1#	!1!ness
# ness	bid	bidness	#1#	!1!ness
# ness	Epic	Epicness	#1#	!1!ness
# ness	joyful	joyfulness	#1#	!1!ness
# ness	hip	hipness	#1#	!1!ness
# ness	Near	Nearness	#1#	!1!ness
# ness	awar	awarness	#1#	!1!ness
# ness	graceful	gracefulness	#1#	!1!ness
# ness	biz	bizness	#1#	!1!ness
# ness	light-headed	light-headedness	#1#	!1!ness
# ness	abrupt	abruptness	#1#	!1!ness
# ness	Strange	Strangeness	#1#	!1!ness
# ness	Forgetful	Forgetfulness	#1#	!1!ness
# ness	blue	blueness	#1#	!1!ness
# ness	funki	funkiness	#1#	!1!ness
# ness	straightforward	straightforwardness	#1#	!1!ness
# ness	offensive	offensiveness	#1#	!1!ness
# ness	listless	listlessness	#1#	!1!ness
# ness	plain	plainness	#1#	!1!ness
# ness	fickle	fickleness	#1#	!1!ness
# ness	Tight	Tightness	#1#	!1!ness
# ness	deft	deftness	#1#	!1!ness
# ness	lean	leanness	#1#	!1!ness
# ness	Strom	Stromness	#1#	!1!ness
# ness	expansive	expansiveness	#1#	!1!ness
# ness	lavish	lavishness	#1#	!1!ness
# ness	Sleepi	Sleepiness	#1#	!1!ness
# ness	wistful	wistfulness	#1#	!1!ness
# ness	crazy	crazyness	#1#	!1!ness
# ness	vile	vileness	#1#	!1!ness
# ness	blank	blankness	#1#	!1!ness
# ness	representative	representativeness	#1#	!1!ness
# ness	Truthful	Truthfulness	#1#	!1!ness
# ness	dead	deadness	#1#	!1!ness
# ness	Self-Aware	Self-Awareness	#1#	!1!ness
# ness	unkind	unkindness	#1#	!1!ness
# ness	Glad	Gladness	#1#	!1!ness
# ness	industrious	industriousness	#1#	!1!ness
# ness	Sou	Souness	#1#	!1!ness
# ness	effortless	effortlessness	#1#	!1!ness
# ness	narrow-minded	narrow-mindedness	#1#	!1!ness
# ness	roomi	roominess	#1#	!1!ness
# ness	single-minded	single-mindedness	#1#	!1!ness
# ness	crude	crudeness	#1#	!1!ness
# ness	sleek	sleekness	#1#	!1!ness
# ness	feeble	feebleness	#1#	!1!ness
# ness	intrusive	intrusiveness	#1#	!1!ness
# ness	Sexi	Sexiness	#1#	!1!ness
# ness	Wicked	Wickedness	#1#	!1!ness
# ness	sure	sureness	#1#	!1!ness
# ness	oblivious	obliviousness	#1#	!1!ness
# ness	Rude	Rudeness	#1#	!1!ness
# ness	skew	skewness	#1#	!1!ness
# ness	adhesive	adhesiveness	#1#	!1!ness
# ness	classi	classiness	#1#	!1!ness
# ness	sighted	sightedness	#1#	!1!ness
# ness	Gentle	Gentleness	#1#	!1!ness
# ness	just	justness	#1#	!1!ness
# ness	Hol	Holness	#1#	!1!ness
# ness	Hopeless	Hopelessness	#1#	!1!ness
# ness	Smooth	Smoothness	#1#	!1!ness
# ness	base	baseness	#1#	!1!ness
# ness	Marchio	Marchioness	#1#	!1!ness
# ness	dirti	dirtiness	#1#	!1!ness
# ness	Restless	Restlessness	#1#	!1!ness
# ness	brash	brashness	#1#	!1!ness
# ness	forthright	forthrightness	#1#	!1!ness
# ness	plump	plumpness	#1#	!1!ness
# ness	handsome	handsomeness	#1#	!1!ness
# ness	adroit	adroitness	#1#	!1!ness
# ness	wanton	wantonness	#1#	!1!ness
# ness	stark	starkness	#1#	!1!ness
# ness	bui	buiness	#1#	!1!ness
# ness	Other	Otherness	#1#	!1!ness
# ness	Ar	Arness	#1#	!1!ness
# ness	Ag	Agness	#1#	!1!ness
# ness	lazy	lazyness	#1#	!1!ness
# ness	grand	grandness	#1#	!1!ness
# ness	unresponsive	unresponsiveness	#1#	!1!ness
# ness	definite	definiteness	#1#	!1!ness
# ness	Bad	Badness	#1#	!1!ness
# ness	quaint	quaintness	#1#	!1!ness
# ness	queer	queerness	#1#	!1!ness
# ness	sparse	sparseness	#1#	!1!ness
# ness	malicious	maliciousness	#1#	!1!ness
# ness	bus	busness	#1#	!1!ness
# ness	knowing	knowingness	#1#	!1!ness
# ness	Cost-Effective	Cost-Effectiveness	#1#	!1!ness
# ness	Vague	Vagueness	#1#	!1!ness
# ness	precarious	precariousness	#1#	!1!ness
# ness	stable	stableness	#1#	!1!ness
# ness	Sleepless	Sleeplessness	#1#	!1!ness
# ness	exquisite	exquisiteness	#1#	!1!ness
# ness	pink	pinkness	#1#	!1!ness
# ness	hapi	hapiness	#1#	!1!ness
# ness	apt	aptness	#1#	!1!ness
# ness	prone	proneness	#1#	!1!ness
# ness	concrete	concreteness	#1#	!1!ness
# ness	Lame	Lameness	#1#	!1!ness
# ness	New	Newness	#1#	!1!ness
# ness	shameless	shamelessness	#1#	!1!ness
# ness	Idle	Idleness	#1#	!1!ness
# ness	rotten	rottenness	#1#	!1!ness
# ness	inattentive	inattentiveness	#1#	!1!ness
# ness	nimble	nimbleness	#1#	!1!ness
# ness	godless	godlessness	#1#	!1!ness
# ness	astute	astuteness	#1#	!1!ness
# ness	Jen	Jenness	#1#	!1!ness
# ness	relentless	relentlessness	#1#	!1!ness
# ness	soulful	soulfulness	#1#	!1!ness
# ness	bullish	bullishness	#1#	!1!ness
# ness	senseless	senselessness	#1#	!1!ness
# ness	airi	airiness	#1#	!1!ness
# ness	safe	safeness	#1#	!1!ness
# ness	high-bright	high-brightness	#1#	!1!ness
# ness	Sound	Soundness	#1#	!1!ness
# ness	Self-aware	Self-awareness	#1#	!1!ness
# ness	noble	nobleness	#1#	!1!ness
# ness	lascivious	lasciviousness	#1#	!1!ness
# ness	handi	handiness	#1#	!1!ness
# ness	gray	grayness	#1#	!1!ness
# ness	intuitive	intuitiveness	#1#	!1!ness
# ness	zani	zaniness	#1#	!1!ness
# ness	tense	tenseness	#1#	!1!ness
# ness	headed	headedness	#1#	!1!ness
# ness	shini	shininess	#1#	!1!ness
# ness	precise	preciseness	#1#	!1!ness
# ness	religious	religiousness	#1#	!1!ness
# ness	crooked	crookedness	#1#	!1!ness
# ness	Lawless	Lawlessness	#1#	!1!ness
# ness	perceptive	perceptiveness	#1#	!1!ness
# ness	Close	Closeness	#1#	!1!ness
# ness	tasti	tastiness	#1#	!1!ness
# ness	huge	hugeness	#1#	!1!ness
# ness	outspoken	outspokenness	#1#	!1!ness
# ness	outrageous	outrageousness	#1#	!1!ness
# ness	mindless	mindlessness	#1#	!1!ness
# ness	drunke	drunkeness	#1#	!1!ness
# ness	Ugli	Ugliness	#1#	!1!ness
# ness	Ridiculous	Ridiculousness	#1#	!1!ness
# ness	obsessive	obsessiveness	#1#	!1!ness
# ness	faithless	faithlessness	#1#	!1!ness
# ness	progressive	progressiveness	#1#	!1!ness
# ness	absolute	absoluteness	#1#	!1!ness
# ness	fake	fakeness	#1#	!1!ness
# ness	In	Inness	#1#	!1!ness
# ness	usefull	usefullness	#1#	!1!ness
# ness	forward	forwardness	#1#	!1!ness
# ness	explicit	explicitness	#1#	!1!ness
# ness	interesting	interestingness	#1#	!1!ness
# ness	silly	sillyness	#1#	!1!ness
# ness	contented	contentedness	#1#	!1!ness
# ness	Wack	Wackness	#1#	!1!ness
# ness	i	iness	#1#	!1!ness
# ness	endian	endianness	#1#	!1!ness
# ness	grim	grimness	#1#	!1!ness
# ness	Connected	Connectedness	#1#	!1!ness
# ness	unreasonable	unreasonableness	#1#	!1!ness
# ness	Incomplete	Incompleteness	#1#	!1!ness
# ness	childless	childlessness	#1#	!1!ness
# ness	forgiv	forgivness	#1#	!1!ness
# ness	stern	sternness	#1#	!1!ness
# ness	addictive	addictiveness	#1#	!1!ness
# ness	Calm	Calmness	#1#	!1!ness
# ness	meticulous	meticulousness	#1#	!1!ness
# ness	dogged	doggedness	#1#	!1!ness
# ness	squeamish	squeamishness	#1#	!1!ness
# ness	slim	slimness	#1#	!1!ness
# ness	grey	greyness	#1#	!1!ness
# ness	inward	inwardness	#1#	!1!ness
# ness	Puffi	Puffiness	#1#	!1!ness
# ness	finite	finiteness	#1#	!1!ness
# ness	comfortable	comfortableness	#1#	!1!ness
# ness	centered	centeredness	#1#	!1!ness
# ness	sucki	suckiness	#1#	!1!ness
# ness	positive	positiveness	#1#	!1!ness
# ness	skillful	skillfulness	#1#	!1!ness
# ness	foul	foulness	#1#	!1!ness
# ness	old	oldness	#1#	!1!ness
# ness	subconscious	subconsciousness	#1#	!1!ness
# ness	devious	deviousness	#1#	!1!ness
# ness	female	femaleness	#1#	!1!ness
# ness	agreeable	agreeableness	#1#	!1!ness
# ness	awesom	awesomness	#1#	!1!ness
# ness	Awkward	Awkwardness	#1#	!1!ness
# ness	cautious	cautiousness	#1#	!1!ness
# ness	Cavi	Caviness	#1#	!1!ness
# ness	simple	simpleness	#1#	!1!ness
# ness	broad	broadness	#1#	!1!ness
# ness	heartless	heartlessness	#1#	!1!ness
# ness	tangi	tanginess	#1#	!1!ness
# ness	harmless	harmlessness	#1#	!1!ness
# ness	mellow	mellowness	#1#	!1!ness
# ness	square	squareness	#1#	!1!ness
# ness	evasive	evasiveness	#1#	!1!ness
# ness	obnoxious	obnoxiousness	#1#	!1!ness
# ness	voluptuous	voluptuousness	#1#	!1!ness
# ness	lighthearted	lightheartedness	#1#	!1!ness
# ness	flawless	flawlessness	#1#	!1!ness
# ness	candid	candidness	#1#	!1!ness
# ness	disinterested	disinterestedness	#1#	!1!ness
# ness	Slow	Slowness	#1#	!1!ness
# ness	Reasonable	Reasonableness	#1#	!1!ness
# ness	bashful	bashfulness	#1#	!1!ness
# ness	dope	dopeness	#1#	!1!ness
# ness	perfect	perfectness	#1#	!1!ness
# ness	interrelated	interrelatedness	#1#	!1!ness
# ness	hideous	hideousness	#1#	!1!ness
# ness	sensuous	sensuousness	#1#	!1!ness
# ness	sadd	saddness	#1#	!1!ness
# ness	Flat	Flatness	#1#	!1!ness
# ness	impressive	impressiveness	#1#	!1!ness
# ness	kinki	kinkiness	#1#	!1!ness
# ness	Shoebury	Shoeburyness	#1#	!1!ness
# ness	little	littleness	#1#	!1!ness
# ness	live	liveness	#1#	!1!ness
# ness	stupid	stupidness	#1#	!1!ness
# ness	stateless	statelessness	#1#	!1!ness
# ness	Delicious	Deliciousness	#1#	!1!ness
# ness	Al	Alness	#1#	!1!ness
# ness	Wild	Wildness	#1#	!1!ness
# ness	perverse	perverseness	#1#	!1!ness
# ness	Meek	Meekness	#1#	!1!ness
# ness	Damp	Dampness	#1#	!1!ness
# ness	Inclusive	Inclusiveness	#1#	!1!ness
# ness	obtuse	obtuseness	#1#	!1!ness
# ness	taut	tautness	#1#	!1!ness
# ness	musti	mustiness	#1#	!1!ness
# ness	funni	funniness	#1#	!1!ness
# ness	dense	denseness	#1#	!1!ness
# ness	signed	signedness	#1#	!1!ness
# ness	Hart	Hartness	#1#	!1!ness
# ness	Broken	Brokenness	#1#	!1!ness
# ness	Swift	Swiftness	#1#	!1!ness
# ness	free	freeness	#1#	!1!ness
# ness	hateful	hatefulness	#1#	!1!ness
# ness	private	privateness	#1#	!1!ness
# ness	uncomfortable	uncomfortableness	#1#	!1!ness
# ness	colorblind	colorblindness	#1#	!1!ness
# ness	brazen	brazenness	#1#	!1!ness
# ness	mysterious	mysteriousness	#1#	!1!ness
# ness	poor	poorness	#1#	!1!ness
# ness	Wet	Wetness	#1#	!1!ness
# ness	Aggressive	Aggressiveness	#1#	!1!ness
# ness	crass	crassness	#1#	!1!ness
# ness	awsome	awsomeness	#1#	!1!ness
# ness	madd	maddness	#1#	!1!ness
# ness	harmful	harmfulness	#1#	!1!ness
# ness	assured	assuredness	#1#	!1!ness
# ness	dreami	dreaminess	#1#	!1!ness
# ness	inert	inertness	#1#	!1!ness
# ness	unexpected	unexpectedness	#1#	!1!ness
# ness	abrasive	abrasiveness	#1#	!1!ness
# ness	tedious	tediousness	#1#	!1!ness
# ness	massive	massiveness	#1#	!1!ness
# ness	resolute	resoluteness	#1#	!1!ness
# ness	Jobless	Joblessness	#1#	!1!ness
# ness	opaque	opaqueness	#1#	!1!ness
# ness	foreign	foreignness	#1#	!1!ness
# ness	effectiv	effectivness	#1#	!1!ness
# ness	Homesick	Homesickness	#1#	!1!ness
# ness	belonging	belongingness	#1#	!1!ness
# ness	demo	demoness	#1#	!1!ness
# ness	capricious	capriciousness	#1#	!1!ness
# ness	sumptuous	sumptuousness	#1#	!1!ness
# ness	waterproof	waterproofness	#1#	!1!ness
# ness	Real	Realness	#1#	!1!ness
# ness	disingenuous	disingenuousness	#1#	!1!ness
# ness	artful	artfulness	#1#	!1!ness
# ness	chilli	chilliness	#1#	!1!ness
# ness	yellow	yellowness	#1#	!1!ness
# ness	true	trueness	#1#	!1!ness
# ness	sheer	sheerness	#1#	!1!ness
# ness	formless	formlessness	#1#	!1!ness
# ness	tall	tallness	#1#	!1!ness
# ness	copious	copiousness	#1#	!1!ness
# ness	Rock	Rockness	#1#	!1!ness
# ness	lightfast	lightfastness	#1#	!1!ness
# ness	competive	competiveness	#1#	!1!ness
# ness	Naked	Nakedness	#1#	!1!ness
# ness	wierd	wierdness	#1#	!1!ness
# ness	common	commonness	#1#	!1!ness
# ness	rooted	rootedness	#1#	!1!ness
# ness	coy	coyness	#1#	!1!ness
# ness	painful	painfulness	#1#	!1!ness
# ness	endless	endlessness	#1#	!1!ness
# ness	embedded	embeddedness	#1#	!1!ness
# ness	sly	slyness	#1#	!1!ness
# ness	void	voidness	#1#	!1!ness
# ness	shrill	shrillness	#1#	!1!ness
# ness	bare	bareness	#1#	!1!ness
# ness	snobbish	snobbishness	#1#	!1!ness
# ness	Unconscious	Unconsciousness	#1#	!1!ness
# ness	Cold	Coldness	#1#	!1!ness
# ness	wide	wideness	#1#	!1!ness
# ness	sinless	sinlessness	#1#	!1!ness
# ness	adventurous	adventurousness	#1#	!1!ness
# ness	snug	snugness	#1#	!1!ness
# ness	Quiet	Quietness	#1#	!1!ness
# ness	Careless	Carelessness	#1#	!1!ness
# ness	aimless	aimlessness	#1#	!1!ness
# ness	colorfast	colorfastness	#1#	!1!ness
# ness	Pure	Pureness	#1#	!1!ness
# ness	wayward	waywardness	#1#	!1!ness
# ness	zealous	zealousness	#1#	!1!ness
# ness	one-sided	one-sidedness	#1#	!1!ness
# ness	unprepared	unpreparedness	#1#	!1!ness
# ness	speedi	speediness	#1#	!1!ness
# ness	Selfless	Selflessness	#1#	!1!ness
# ness	much	muchness	#1#	!1!ness
# ness	left-handed	left-handedness	#1#	!1!ness
# ness	hearted	heartedness	#1#	!1!ness
# ness	combative	combativeness	#1#	!1!ness
# ness	hairi	hairiness	#1#	!1!ness
# ness	Dur	Durness	#1#	!1!ness
# ness	expert	expertness	#1#	!1!ness
# ness	humane	humaneness	#1#	!1!ness
# ness	tasteful	tastefulness	#1#	!1!ness
# ness	Single	Singleness	#1#	!1!ness
# ness	bizarre	bizarreness	#1#	!1!ness
# ness	luxurious	luxuriousness	#1#	!1!ness
# ness	hott	hottness	#1#	!1!ness
# ness	Grateful	Gratefulness	#1#	!1!ness
# ness	Fearless	Fearlessness	#1#	!1!ness
# ness	moot	mootness	#1#	!1!ness
# ness	passive	passiveness	#1#	!1!ness
# ness	sexy	sexyness	#1#	!1!ness
# ness	slender	slenderness	#1#	!1!ness
# ness	Van	Vanness	#1#	!1!ness
# ness	dizzy	dizzyness	#1#	!1!ness
# ness	si	siness	#1#	!1!ness
# ness	dear	dearness	#1#	!1!ness
# ness	achi	achiness	#1#	!1!ness
# ness	auspicious	auspiciousness	#1#	!1!ness
# ness	Ly	Lyness	#1#	!1!ness
# ness	brave	braveness	#1#	!1!ness
# ness	Patro	Patroness	#1#	!1!ness
# ness	heedless	heedlessness	#1#	!1!ness
# ness	horrible	horribleness	#1#	!1!ness
# ness	Cross	Crossness	#1#	!1!ness
# ness	joyous	joyousness	#1#	!1!ness
# ness	Gifted	Giftedness	#1#	!1!ness
# ness	Irish	Irishness	#1#	!1!ness
# ness	woodi	woodiness	#1#	!1!ness
# ness	Air	Airness	#1#	!1!ness
# ness	excessive	excessiveness	#1#	!1!ness
# ness	semi-dark	semi-darkness	#1#	!1!ness
# ness	Dope	Dopeness	#1#	!1!ness
# ness	Reckless	Recklessness	#1#	!1!ness
# ness	suggestive	suggestiveness	#1#	!1!ness
# ness	extensive	extensiveness	#1#	!1!ness
# ness	impecunious	impecuniousness	#1#	!1!ness
# ness	mischievous	mischievousness	#1#	!1!ness
# ness	powerful	powerfulness	#1#	!1!ness
# ness	Fat	Fatness	#1#	!1!ness
# ness	Busy	Busyness	#1#	!1!ness
# ness	feckless	fecklessness	#1#	!1!ness
# ness	consious	consiousness	#1#	!1!ness
# ness	Late	Lateness	#1#	!1!ness
# ness	minute	minuteness	#1#	!1!ness
# ness	low	lowness	#1#	!1!ness
# ness	restful	restfulness	#1#	!1!ness
# ness	Awar	Awarness	#1#	!1!ness
# ness	empty	emptyness	#1#	!1!ness
# ness	contentious	contentiousness	#1#	!1!ness
# ness	Lumi	Luminess	#1#	!1!ness
# ness	secretive	secretiveness	#1#	!1!ness
# ness	Fine	Fineness	#1#	!1!ness
# ness	heavy-handed	heavy-handedness	#1#	!1!ness
# ness	god	godness	#1#	!1!ness
# ness	Sticki	Stickiness	#1#	!1!ness
# ness	bearish	bearishness	#1#	!1!ness
# ness	Hoarse	Hoarseness	#1#	!1!ness
# ness	feverish	feverishness	#1#	!1!ness
# ness	light-hearted	light-heartedness	#1#	!1!ness
# ness	Clever	Cleverness	#1#	!1!ness
# ness	Resourceful	Resourcefulness	#1#	!1!ness
# ness	subtle	subtleness	#1#	!1!ness
# ness	abstract	abstractness	#1#	!1!ness
# ness	Cheerful	Cheerfulness	#1#	!1!ness
# ness	Interesting	Interestingness	#1#	!1!ness
# ness	dorki	dorkiness	#1#	!1!ness
# ness	Christlike	Christlikeness	#1#	!1!ness
# ness	even-handed	even-handedness	#1#	!1!ness
# ness	profound	profoundness	#1#	!1!ness
# ness	acquisitive	acquisitiveness	#1#	!1!ness
# ness	succinct	succinctness	#1#	!1!ness
# ness	rare	rareness	#1#	!1!ness
# ness	sassi	sassiness	#1#	!1!ness
# ness	sober	soberness	#1#	!1!ness
# ness	disconnected	disconnectedness	#1#	!1!ness
# ness	deliberate	deliberateness	#1#	!1!ness
# ness	campi	campiness	#1#	!1!ness
# ness	lost	lostness	#1#	!1!ness
# ness	fur	furness	#1#	!1!ness
# ness	Gun	Gunness	#1#	!1!ness
# ness	Va	Vaness	#1#	!1!ness
# ness	solid	solidness	#1#	!1!ness
# ness	Bid	Bidness	#1#	!1!ness
# ness	Madd	Maddness	#1#	!1!ness
# ness	Playful	Playfulness	#1#	!1!ness
# ness	Tardi	Tardiness	#1#	!1!ness
# ness	Nice	Niceness	#1#	!1!ness
# ness	infectious	infectiousness	#1#	!1!ness
# ness	unlawful	unlawfulness	#1#	!1!ness
# ness	prudish	prudishness	#1#	!1!ness
# ness	terrible	terribleness	#1#	!1!ness
# ness	airtight	airtightness	#1#	!1!ness
# ness	mute	muteness	#1#	!1!ness
# ness	picki	pickiness	#1#	!1!ness
# ness	boring	boringness	#1#	!1!ness
# ness	seamless	seamlessness	#1#	!1!ness
# ness	fastidious	fastidiousness	#1#	!1!ness
# ness	fanci	fanciness	#1#	!1!ness
# ness	unsound	unsoundness	#1#	!1!ness
# ness	spirited	spiritedness	#1#	!1!ness
# ness	rigid	rigidness	#1#	!1!ness
# ness	suspicious	suspiciousness	#1#	!1!ness
# ness	accurate	accurateness	#1#	!1!ness
# ness	luscious	lusciousness	#1#	!1!ness
# ness	brisk	briskness	#1#	!1!ness
# ness	absent-minded	absent-mindedness	#1#	!1!ness
# ness	Conscientious	Conscientiousness	#1#	!1!ness
# ness	Deep	Deepness	#1#	!1!ness
# ness	ludicrous	ludicrousness	#1#	!1!ness
# ness	tentative	tentativeness	#1#	!1!ness
# ness	slothful	slothfulness	#1#	!1!ness
# ness	obsequious	obsequiousness	#1#	!1!ness
# ness	lifeless	lifelessness	#1#	!1!ness
# ness	Concious	Conciousness	#1#	!1!ness
# ness	successful	successfulness	#1#	!1!ness
# ness	Neat	Neatness	#1#	!1!ness
# ness	Nearsighted	Nearsightedness	#1#	!1!ness
# ness	mushi	mushiness	#1#	!1!ness
# ness	literal	literalness	#1#	!1!ness
# ness	tasteless	tastelessness	#1#	!1!ness
# ness	glib	glibness	#1#	!1!ness
# ness	untruthful	untruthfulness	#1#	!1!ness
# ness	scarce	scarceness	#1#	!1!ness
# ness	corni	corniness	#1#	!1!ness
# ness	Same	Sameness	#1#	!1!ness
# ness	bounded	boundedness	#1#	!1!ness
# ness	Fond	Fondness	#1#	!1!ness
# ness	ferocious	ferociousness	#1#	!1!ness
# ness	Stubborn	Stubbornness	#1#	!1!ness
# ness	Thorpe	Thorpeness	#1#	!1!ness
# ness	Itchi	Itchiness	#1#	!1!ness
# ness	rad	radness	#1#	!1!ness
# ness	such	suchness	#1#	!1!ness
# ness	Loch	Lochness	#1#	!1!ness
# ness	Gay	Gayness	#1#	!1!ness
# ness	fi	finess	#1#	!1!ness
# ness	dubious	dubiousness	#1#	!1!ness
# ness	k	kness	#1#	!1!ness
# ness	Powerless	Powerlessness	#1#	!1!ness
# ness	Cocki	Cockiness	#1#	!1!ness
# ness	Self-Conscious	Self-Consciousness	#1#	!1!ness
# ness	terse	terseness	#1#	!1!ness
# ness	devoted	devotedness	#1#	!1!ness
# ness	flexible	flexibleness	#1#	!1!ness
# ness	Cham	Chamness	#1#	!1!ness
# ness	Unfair	Unfairness	#1#	!1!ness
# ness	Covetous	Covetousness	#1#	!1!ness
# ness	grassi	grassiness	#1#	!1!ness
# ness	Crafti	Craftiness	#1#	!1!ness
# ness	plush	plushness	#1#	!1!ness
# ness	ici	iciness	#1#	!1!ness
# ness	skilful	skilfulness	#1#	!1!ness
# ness	incisive	incisiveness	#1#	!1!ness
# ness	broke	brokeness	#1#	!1!ness
# ness	sappi	sappiness	#1#	!1!ness
# ness	Big	Bigness	#1#	!1!ness
# ness	impervious	imperviousness	#1#	!1!ness
# ness	mean-spirited	mean-spiritedness	#1#	!1!ness
# ness	indefinite	indefiniteness	#1#	!1!ness
# ness	Eager	Eagerness	#1#	!1!ness
# ness	week	weekness	#1#	!1!ness
# ness	fatherless	fatherlessness	#1#	!1!ness
# ness	delicate	delicateness	#1#	!1!ness
# ness	God-conscious	God-consciousness	#1#	!1!ness
# ness	fleet	fleetness	#1#	!1!ness
# ness	well-formed	well-formedness	#1#	!1!ness
# ness	Fuzzi	Fuzziness	#1#	!1!ness
# ness	dul	dulness	#1#	!1!ness
# ness	Anxious	Anxiousness	#1#	!1!ness
# ness	speechless	speechlessness	#1#	!1!ness
# ness	drab	drabness	#1#	!1!ness
# ness	Handed	Handedness	#1#	!1!ness
# ness	limp	limpness	#1#	!1!ness
# ness	Related	Relatedness	#1#	!1!ness
# ness	discrete	discreteness	#1#	!1!ness
# ness	high-minded	high-mindedness	#1#	!1!ness
# ness	Dear	Dearness	#1#	!1!ness
# ness	wounded	woundedness	#1#	!1!ness
# ness	Compact	Compactness	#1#	!1!ness
# ness	Prompt	Promptness	#1#	!1!ness
# ness	insightful	insightfulness	#1#	!1!ness
# ness	nosi	nosiness	#1#	!1!ness
# ness	Timeless	Timelessness	#1#	!1!ness
# ness	boastful	boastfulness	#1#	!1!ness
# ness	earli	earliness	#1#	!1!ness
# ness	Stateless	Statelessness	#1#	!1!ness
# ness	unattractive	unattractiveness	#1#	!1!ness
# ness	shadi	shadiness	#1#	!1!ness
# ness	fitt	fittness	#1#	!1!ness
# ness	wrongful	wrongfulness	#1#	!1!ness
# ness	grounded	groundedness	#1#	!1!ness
# ness	open-ended	open-endedness	#1#	!1!ness
# ness	spineless	spinelessness	#1#	!1!ness
# ness	freaki	freakiness	#1#	!1!ness
# ness	talkative	talkativeness	#1#	!1!ness
# ness	skeg	skegness	#1#	!1!ness
# ness	Christ-like	Christ-likeness	#1#	!1!ness
# ness	Otter	Otterness	#1#	!1!ness
# ness	Sacred	Sacredness	#1#	!1!ness
# ness	Distinctive	Distinctiveness	#1#	!1!ness
# ness	lukewarm	lukewarmness	#1#	!1!ness
# ness	busin	businness	#1#	!1!ness
# ness	Ve	Veness	#1#	!1!ness
# ness	abusive	abusiveness	#1#	!1!ness
# ness	bisi	bisiness	#1#	!1!ness
# ness	bis	bisness	#1#	!1!ness
# ness	hasti	hastiness	#1#	!1!ness
# ness	virtuous	virtuousness	#1#	!1!ness
# ness	Rad	Radness	#1#	!1!ness
# ness	evenhanded	evenhandedness	#1#	!1!ness
# ness	primitive	primitiveness	#1#	!1!ness
# ness	closed-minded	closed-mindedness	#1#	!1!ness
# ness	badass	badassness	#1#	!1!ness
# ness	respectful	respectfulness	#1#	!1!ness
# ness	Blessed	Blessedness	#1#	!1!ness
# ness	bossi	bossiness	#1#	!1!ness
# ness	japa	japaness	#1#	!1!ness
# ness	sea-sick	sea-sickness	#1#	!1!ness
# ness	chic	chicness	#1#	!1!ness
# ness	fixed	fixedness	#1#	!1!ness
# ness	Harsh	Harshness	#1#	!1!ness
# ness	Unwilling	Unwillingness	#1#	!1!ness
# ness	retarded	retardedness	#1#	!1!ness
# ness	Peaceful	Peacefulness	#1#	!1!ness
# ness	rootless	rootlessness	#1#	!1!ness
# ness	icki	ickiness	#1#	!1!ness
# ness	facetious	facetiousness	#1#	!1!ness
# ness	boorish	boorishness	#1#	!1!ness
# ness	hale	haleness	#1#	!1!ness
# ness	picturesque	picturesqueness	#1#	!1!ness
# ness	tame	tameness	#1#	!1!ness
# ness	close-minded	close-mindedness	#1#	!1!ness
# ness	absentminded	absentmindedness	#1#	!1!ness
# ness	glorious	gloriousness	#1#	!1!ness
# ness	Lyo	Lyoness	#1#	!1!ness
# ness	wilful	wilfulness	#1#	!1!ness
# ness	stout	stoutness	#1#	!1!ness
# ness	Hoe	Hoeness	#1#	!1!ness
# ness	skittish	skittishness	#1#	!1!ness
# ness	ungrateful	ungratefulness	#1#	!1!ness
# ness	Remote	Remoteness	#1#	!1!ness
# ness	purposeless	purposelessness	#1#	!1!ness
# ness	possible	possibleness	#1#	!1!ness
# ness	spiteful	spitefulness	#1#	!1!ness
# ness	dismissive	dismissiveness	#1#	!1!ness
# ness	far-sighted	far-sightedness	#1#	!1!ness
# ness	gaudi	gaudiness	#1#	!1!ness
# ness	Vast	Vastness	#1#	!1!ness
# ness	Fast	Fastness	#1#	!1!ness
# ness	presumptuous	presumptuousness	#1#	!1!ness
# ness	spicy	spicyness	#1#	!1!ness
# ness	Thoughtful	Thoughtfulness	#1#	!1!ness
# ness	stuck	stuckness	#1#	!1!ness
# ness	workless	worklessness	#1#	!1!ness
# ness	sullen	sullenness	#1#	!1!ness
# ness	oppressive	oppressiveness	#1#	!1!ness
# ness	hark	harkness	#1#	!1!ness
# ness	lax	laxness	#1#	!1!ness
# ness	compulsive	compulsiveness	#1#	!1!ness
# ness	heinous	heinousness	#1#	!1!ness
# ness	vigorous	vigorousness	#1#	!1!ness
# ness	self-assured	self-assuredness	#1#	!1!ness
# ness	Obvious	Obviousness	#1#	!1!ness
# ness	Thin	Thinness	#1#	!1!ness
# ness	Strict	Strictness	#1#	!1!ness
# ness	wack	wackness	#1#	!1!ness
# ness	Indian	Indianness	#1#	!1!ness
# ness	scali	scaliness	#1#	!1!ness
# ness	game	gameness	#1#	!1!ness
# ness	Wakeful	Wakefulness	#1#	!1!ness
# ness	trite	triteness	#1#	!1!ness
# ness	limitless	limitlessness	#1#	!1!ness
# ness	unlike	unlikeness	#1#	!1!ness
# ness	Dull	Dullness	#1#	!1!ness
# ness	blissful	blissfulness	#1#	!1!ness
# ness	courteous	courteousness	#1#	!1!ness
# ness	Straight	Straightness	#1#	!1!ness
# ness	gruff	gruffness	#1#	!1!ness
# ness	hairless	hairlessness	#1#	!1!ness
# ness	authoritative	authoritativeness	#1#	!1!ness
# ness	geek	geekness	#1#	!1!ness
# ness	corrupt	corruptness	#1#	!1!ness
# ness	high-handed	high-handedness	#1#	!1!ness
# ness	Farsighted	Farsightedness	#1#	!1!ness
# ness	cussed	cussedness	#1#	!1!ness
# ness	Green	Greenness	#1#	!1!ness
# ness	Sinful	Sinfulness	#1#	!1!ness
# ness	gruesome	gruesomeness	#1#	!1!ness
# ness	bsi	bsiness	#1#	!1!ness
# ness	Sturdi	Sturdiness	#1#	!1!ness
# ness	devout	devoutness	#1#	!1!ness
# ness	reflective	reflectiveness	#1#	!1!ness
# ness	Lax	Laxness	#1#	!1!ness
# ness	Defensive	Defensiveness	#1#	!1!ness
# ness	An	Anness	#1#	!1!ness
# ness	Con	Conness	#1#	!1!ness
# ness	Thorough	Thoroughness	#1#	!1!ness
# ness	girli	girliness	#1#	!1!ness
# ness	touchi	touchiness	#1#	!1!ness
# ness	Colorblind	Colorblindness	#1#	!1!ness
# ness	Effectiv	Effectivness	#1#	!1!ness
# ness	agressive	agressiveness	#1#	!1!ness
# ness	showi	showiness	#1#	!1!ness
# ness	deceptive	deceptiveness	#1#	!1!ness
# ness	level-headed	level-headedness	#1#	!1!ness
# ness	defective	defectiveness	#1#	!1!ness
# ness	cleani	cleaniness	#1#	!1!ness
# ness	clear-sighted	clear-sightedness	#1#	!1!ness
# ness	boundless	boundlessness	#1#	!1!ness
# ness	grotesque	grotesqueness	#1#	!1!ness
# ness	Being	Beingness	#1#	!1!ness
# ness	tuneful	tunefulness	#1#	!1!ness
# ness	Clear	Clearness	#1#	!1!ness
# ness	Fabulous	Fabulousness	#1#	!1!ness
# ness	Funni	Funniness	#1#	!1!ness
# ness	hidden	hiddenness	#1#	!1!ness
# ness	Youthful	Youthfulness	#1#	!1!ness
# ness	bilious	biliousness	#1#	!1!ness
# ness	fallen	fallenness	#1#	!1!ness
# ness	cooperative	cooperativeness	#1#	!1!ness
# ness	wili	wiliness	#1#	!1!ness
# ness	small-minded	small-mindedness	#1#	!1!ness
# ness	airsick	airsickness	#1#	!1!ness
# ness	Fi	Finess	#1#	!1!ness
# ness	Weightless	Weightlessness	#1#	!1!ness
# ness	pushi	pushiness	#1#	!1!ness
# ness	tearful	tearfulness	#1#	!1!ness
# ness	salubrious	salubriousness	#1#	!1!ness
# ness	color-blind	color-blindness	#1#	!1!ness
# ness	Fruitful	Fruitfulness	#1#	!1!ness
# ness	artless	artlessness	#1#	!1!ness
# ness	objective	objectiveness	#1#	!1!ness
# ness	between	betweenness	#1#	!1!ness
# ness	tenacious	tenaciousness	#1#	!1!ness
# ness	Vangs	Vangsness	#1#	!1!ness
# ness	insidious	insidiousness	#1#	!1!ness
# ness	Lightheaded	Lightheadedness	#1#	!1!ness
# ness	Bo	Boness	#1#	!1!ness
# ness	Ripe	Ripeness	#1#	!1!ness
# ness	Ful	Fulness	#1#	!1!ness
# ness	apprehensive	apprehensiveness	#1#	!1!ness
# ness	inter-connected	inter-connectedness	#1#	!1!ness
# ness	brief	briefness	#1#	!1!ness
# ness	hilarious	hilariousness	#1#	!1!ness
# ness	everyday	everydayness	#1#	!1!ness
# ness	sordid	sordidness	#1#	!1!ness
# ness	Unpleasant	Unpleasantness	#1#	!1!ness
# ness	Unfaithful	Unfaithfulness	#1#	!1!ness
# ness	fieri	fieriness	#1#	!1!ness
# ness	doubtful	doubtfulness	#1#	!1!ness
# ness	Turkish	Turkishness	#1#	!1!ness
# ness	fretful	fretfulness	#1#	!1!ness
# ness	suitable	suitableness	#1#	!1!ness
# ness	self-centred	self-centredness	#1#	!1!ness
# ness	somber	somberness	#1#	!1!ness
# ness	entire	entireness	#1#	!1!ness
# ness	fatti	fattiness	#1#	!1!ness
# ness	pompous	pompousness	#1#	!1!ness
# ness	Skew	Skewness	#1#	!1!ness
# ness	colorful	colorfulness	#1#	!1!ness
# ness	peevish	peevishness	#1#	!1!ness
# ness	all-inclusive	all-inclusiveness	#1#	!1!ness
# ness	Attentive	Attentiveness	#1#	!1!ness
# ness	ingenuous	ingenuousness	#1#	!1!ness
# ness	spare	spareness	#1#	!1!ness
# ness	Interconnected	Interconnectedness	#1#	!1!ness
# ness	needful	needfulness	#1#	!1!ness
# ness	near-sighted	near-sightedness	#1#	!1!ness
# ness	expensive	expensiveness	#1#	!1!ness
# ness	Breathless	Breathlessness	#1#	!1!ness
# ness	Expressive	Expressiveness	#1#	!1!ness
# ness	Self-conscious	Self-consciousness	#1#	!1!ness
# ness	Demo	Demoness	#1#	!1!ness
# ness	Round	Roundness	#1#	!1!ness
# ness	bittersweet	bittersweetness	#1#	!1!ness
# ness	chatti	chattiness	#1#	!1!ness
# ness	public	publicness	#1#	!1!ness
# ness	il	ilness	#1#	!1!ness
# ness	precocious	precociousness	#1#	!1!ness
# ness	girlish	girlishness	#1#	!1!ness
# ness	bias	biasness	#1#	!1!ness
# ness	restrictive	restrictiveness	#1#	!1!ness
# ness	Sten	Stenness	#1#	!1!ness
# ness	Kinki	Kinkiness	#1#	!1!ness
# ness	Sade	Sadeness	#1#	!1!ness
# ness	Odd	Oddness	#1#	!1!ness
# ness	brown	brownness	#1#	!1!ness
# ness	eco-conscious	eco-consciousness	#1#	!1!ness
# ness	unnatural	unnaturalness	#1#	!1!ness
# ness	retentive	retentiveness	#1#	!1!ness
# ness	matter-of-fact	matter-of-factness	#1#	!1!ness
# ness	American	Americanness	#1#	!1!ness
# ness	Contented	Contentedness	#1#	!1!ness
# ness	Seasick	Seasickness	#1#	!1!ness
# ness	reclusive	reclusiveness	#1#	!1!ness
# ness	Alone	Aloneness	#1#	!1!ness
# ness	Natural	Naturalness	#1#	!1!ness
# ness	vivacious	vivaciousness	#1#	!1!ness
# ness	conclusive	conclusiveness	#1#	!1!ness
# ness	Hapi	Hapiness	#1#	!1!ness
# ness	savage	savageness	#1#	!1!ness
# ness	friendly	friendlyness	#1#	!1!ness
# ness	bloated	bloatedness	#1#	!1!ness
# ness	gregarious	gregariousness	#1#	!1!ness
# ness	non-responsive	non-responsiveness	#1#	!1!ness
# ness	now	nowness	#1#	!1!ness
# ness	bushi	bushiness	#1#	!1!ness
# ness	ingenious	ingeniousness	#1#	!1!ness
# ness	Agreeable	Agreeableness	#1#	!1!ness
# ness	supportive	supportiveness	#1#	!1!ness
# ness	Godless	Godlessness	#1#	!1!ness
# ness	pious	piousness	#1#	!1!ness
# ness	lonely	lonelyness	#1#	!1!ness
# ness	headi	headiness	#1#	!1!ness
# ness	Bars	Barsness	#1#	!1!ness
# ness	judicious	judiciousness	#1#	!1!ness
# ness	boyish	boyishness	#1#	!1!ness
# ness	hawt	hawtness	#1#	!1!ness
# ness	valid	validness	#1#	!1!ness
# ness	unwell	unwellness	#1#	!1!ness
# ness	Alive	Aliveness	#1#	!1!ness
# ness	impetuous	impetuousness	#1#	!1!ness
# ness	impolite	impoliteness	#1#	!1!ness
# ness	landless	landlessness	#1#	!1!ness
# ness	beautiful	beautifulness	#1#	!1!ness
# ness	variable	variableness	#1#	!1!ness
# ness	freakish	freakishness	#1#	!1!ness
# ness	Cheap	Cheapness	#1#	!1!ness
# ness	Gorgeous	Gorgeousness	#1#	!1!ness
# ness	level	levelness	#1#	!1!ness
# ness	Creative	Creativeness	#1#	!1!ness
# ness	imaginative	imaginativeness	#1#	!1!ness
# ness	GoFit	GoFitness	#1#	!1!ness
# ness	Easi	Easiness	#1#	!1!ness
# ness	Now	Nowness	#1#	!1!ness
# ness	Useless	Uselessness	#1#	!1!ness
# ness	self-destructive	self-destructiveness	#1#	!1!ness
# ness	conspicuous	conspicuousness	#1#	!1!ness
# ness	eco-aware	eco-awareness	#1#	!1!ness
# ness	litigious	litigiousness	#1#	!1!ness
# ness	vengeful	vengefulness	#1#	!1!ness
# ness	repulsive	repulsiveness	#1#	!1!ness
# ness	Ineffective	Ineffectiveness	#1#	!1!ness
# ness	innate	innateness	#1#	!1!ness
# ness	sane	saneness	#1#	!1!ness
# ness	Game	Gameness	#1#	!1!ness
# ness	Par	Parness	#1#	!1!ness
# ness	overzealous	overzealousness	#1#	!1!ness
# ness	ugly	uglyness	#1#	!1!ness
# ness	rosi	rosiness	#1#	!1!ness
# ness	God	Godness	#1#	!1!ness
# ness	Bui	Buiness	#1#	!1!ness
# ness	heedful	heedfulness	#1#	!1!ness
# ness	Dork	Dorkness	#1#	!1!ness
# ness	contagious	contagiousness	#1#	!1!ness
# ness	vacuous	vacuousness	#1#	!1!ness
# ...
# oid	Ande	Andoid	#1#e	!1!oid
# oid	triterpene	triterpenoid	#1#e	!1!oid
# oid	terpene	terpenoid	#1#e	!1!oid
# oid	Gee	Geoid	#1#e	!1!oid
# oid	matre	matroid	#1#e	!1!oid
# oid	Tere	Teroid	#1#e	!1!oid
# oid	Planete	Planetoid	#1#e	!1!oid
# oid	vanille	vanilloid	#1#e	!1!oid
# oid	Astre	Astroid	#1#e	!1!oid
# oid	amygdale	amygdaloid	#1#e	!1!oid
# oid	hyperbole	hyperboloid	#1#e	!1!oid
# oid	blocke	blockoid	#1#e	!1!oid
# oid	Sphere	Spheroid	#1#e	!1!oid
# oid	talbe	talboid	#1#e	!1!oid
# oid	Chore	Choroid	#1#e	!1!oid
# oid	techne	technoid	#1#e	!1!oid
# oid	lipe	lipoid	#1#e	!1!oid
# oid	Adre	Adroid	#1#e	!1!oid
# oid	alte	altoid	#1#e	!1!oid
# oid	Oxe	Oxoid	#1#e	!1!oid
# oid	Hype	Hypoid	#1#e	!1!oid
# oid	be	boid	#1#e	!1!oid
# oid	Crine	Crinoid	#1#e	!1!oid
# oid	Chancre	Chancroid	#1#e	!1!oid
# oid	vire	viroid	#1#e	!1!oid
# oid	obove	obovoid	#1#e	!1!oid
# oid	Monge	Mongoid	#1#e	!1!oid
# oid	are	aroid	#1#e	!1!oid
# oid	te	toid	#1#e	!1!oid
# oid	arcane	arcanoid	#1#e	!1!oid
# oid	Fle	Floid	#1#e	!1!oid
# oid	Sphene	Sphenoid	#1#e	!1!oid
# oid	grabe	graboid	#1#e	!1!oid
# oid	cere	ceroid	#1#e	!1!oid
# oid	Hale	Haloid	#1#e	!1!oid
# oid	Techne	Technoid	#1#e	!1!oid
# oid	Xe	Xoid	#1#e	!1!oid
# oid	Gyne	Gynoid	#1#e	!1!oid
# oid	thre	throid	#1#e	!1!oid
# oid	Loce	Locoid	#1#e	!1!oid
# oid	granite	granitoid	#1#e	!1!oid
# oid	Mandre	Mandroid	#1#e	!1!oid
# oid	Cycle	Cycloid	#1#e	!1!oid
# oid	Maste	Mastoid	#1#e	!1!oid
# oid	adre	adroid	#1#e	!1!oid
# oid	dragone	dragonoid	#1#e	!1!oid
# oid	gyne	gynoid	#1#e	!1!oid
# oid	Are	Aroid	#1#e	!1!oid
# oid	zoe	zooid	#1#e	!1!oid
# oid	Triple	Triploid	#1#e	!1!oid
# oid	dte	dtoid	#1#e	!1!oid
# oid	Parasite	Parasitoid	#1#e	!1!oid
# oid	basale	basaloid	#1#e	!1!oid
# oid	ge	goid	#1#e	!1!oid
# oid	Bare	Baroid	#1#e	!1!oid
# oid	Battre	Battroid	#1#e	!1!oid
# oid	resine	resinoid	#1#e	!1!oid
# oid	le	loid	#1#e	!1!oid
# oid	Australe	Australoid	#1#e	!1!oid
# oid	cocce	coccoid	#1#e	!1!oid
# oid	adve	advoid	#1#e	!1!oid
# oid	mye	myoid	#1#e	!1!oid
# oid	monge	mongoid	#1#e	!1!oid
# oid	Ce	Coid	#1#e	!1!oid
# oid	selene	selenoid	#1#e	!1!oid
# oid	Desme	Desmoid	#1#e	!1!oid
# oid	bice	bicoid	#1#e	!1!oid
# oid	Hye	Hyoid	#1#e	!1!oid
# oid	Bice	Bicoid	#1#e	!1!oid
# oid	ande	andoid	#1#e	!1!oid
# oid	Funge	Fungoid	#1#e	!1!oid
# oid	Le	Loid	#1#e	!1!oid
# oid	anre	anroid	#1#e	!1!oid
# oid	Adapte	Adaptoid	#1#e	!1!oid
# oid	diterpene	diterpenoid	#1#e	!1!oid
# oid	cone	conoid	#1#e	!1!oid
# oid	Helice	Helicoid	#1#e	!1!oid
# oid	Nedre	Nedroid	#1#e	!1!oid
# oid	neve	nevoid	#1#e	!1!oid
# oid	Qube	Quboid	#1#e	!1!oid
# oid	Matre	Matroid	#1#e	!1!oid
# oid	Salmone	Salmonoid	#1#e	!1!oid
# oid	se	soid	#1#e	!1!oid
# oid	Zoe	Zooid	#1#e	!1!oid
# oid	sleaze	sleazoid	#1#e	!1!oid
# oid	phote	photoid	#1#e	!1!oid
# oid	Hyperbole	Hyperboloid	#1#e	!1!oid
# oid	Mute	Mutoid	#1#e	!1!oid
# oid	Angele	Angeloid	#1#e	!1!oid
# oid	organe	organoid	#1#e	!1!oid
# oid	Sesame	Sesamoid	#1#e	!1!oid
# oid	ope	opoid	#1#e	!1!oid
# oid	fe	foid	#1#e	!1!oid
# oid	Lipe	Lipoid	#1#e	!1!oid
# oid	isoflavone	isoflavonoid	#1#e	!1!oid
# oid	torre	torroid	#1#e	!1!oid
# oid	tyre	tyroid	#1#e	!1!oid
# oid	globe	globoid	#1#e	!1!oid
# oid	dve	dvoid	#1#e	!1!oid
# oid	he	hoid	#1#e	!1!oid
# oid	gyre	gyroid	#1#e	!1!oid
# oid	we	woid	#1#e	!1!oid
# oid	de	doid	#1#e	!1!oid
# oid	Sleaze	Sleazoid	#1#e	!1!oid
# oid	lefte	leftoid	#1#e	!1!oid
# oid	Menze	Menzoid	#1#e	!1!oid
# oid	Gyre	Gyroid	#1#e	!1!oid
# oid	gane	ganoid	#1#e	!1!oid
# oid	Cere	Ceroid	#1#e	!1!oid
# oid	place	placoid	#1#e	!1!oid
# oid	loce	locoid	#1#e	!1!oid
# oid	ce	coid	#1#e	!1!oid
# oid	ndre	ndroid	#1#e	!1!oid
# oid	benzene	benzenoid	#1#e	!1!oid
# oid	Me	Moid	#1#e	!1!oid
# oid	condyle	condyloid	#1#e	!1!oid
# oid	proteine	proteinoid	#1#e	!1!oid
# oid	Matte	Mattoid	#1#e	!1!oid
# oid	zombe	zomboid	#1#e	!1!oid
# oid	clothe	clothoid	#1#e	!1!oid
# oid	feline	felinoid	#1#e	!1!oid
# oid	Resine	Resinoid	#1#e	!1!oid
# oid	Pe	Poid	#1#e	!1!oid
# oid	Merce	Mercoid	#1#e	!1!oid
# oid	Battle	Battloid	#1#e	!1!oid
# oid	troche	trochoid	#1#e	!1!oid
# oid	Parabole	Paraboloid	#1#e	!1!oid
# oid	Organe	Organoid	#1#e	!1!oid
# oid	Terpene	Terpenoid	#1#e	!1!oid
# oid	ovale	ovaloid	#1#e	!1!oid
# oid	progresse	progressoid	#1#e	!1!oid
# oid	Therme	Thermoid	#1#e	!1!oid
# oid	monocyte	monocytoid	#1#e	!1!oid
# oid	Vanille	Vanilloid	#1#e	!1!oid
#
#
#
# !1!oid
# #1#
#
#
#
# oid	av	avoid	#1#	!1!oid
# oid	Andr	Android	#1#	!1!oid
# oid	v	void	#1#	!1!oid
# oid	Av	Avoid	#1#	!1!oid
# oid	andr	android	#1#	!1!oid
# oid	thyr	thyroid	#1#	!1!oid
# oid	Dr	Droid	#1#	!1!oid
# oid	paran	paranoid	#1#	!1!oid
# oid	ster	steroid	#1#	!1!oid
# oid	dev	devoid	#1#	!1!oid
# oid	V	Void	#1#	!1!oid
# oid	aster	asteroid	#1#	!1!oid
# oid	dr	droid	#1#	!1!oid
# oid	tabl	tabloid	#1#	!1!oid
# oid	Polar	Polaroid	#1#	!1!oid
# oid	Thyr	Thyroid	#1#	!1!oid
# oid	solen	solenoid	#1#	!1!oid
# oid	Metr	Metroid	#1#	!1!oid
# oid	opi	opioid	#1#	!1!oid
# oid	human	humanoid	#1#	!1!oid
# oid	Aster	Asteroid	#1#	!1!oid
# oid	Paran	Paranoid	#1#	!1!oid
# oid	Solen	Solenoid	#1#	!1!oid
# oid	amyl	amyloid	#1#	!1!oid
# oid	Ster	Steroid	#1#	!1!oid
# oid	Vocal	Vocaloid	#1#	!1!oid
# oid	polar	polaroid	#1#	!1!oid
# oid	Tabl	Tabloid	#1#	!1!oid
# oid	lymph	lymphoid	#1#	!1!oid
# oid	fact	factoid	#1#	!1!oid
# oid	Human	Humanoid	#1#	!1!oid
# oid	fibr	fibroid	#1#	!1!oid
# oid	Destruct	Destructoid	#1#	!1!oid
# oid	metr	metroid	#1#	!1!oid
# oid	Opi	Opioid	#1#	!1!oid
# oid	coll	colloid	#1#	!1!oid
# oid	cardi	cardioid	#1#	!1!oid
# oid	dipl	diploid	#1#	!1!oid
# oid	trapez	trapezoid	#1#	!1!oid
# oid	centr	centroid	#1#	!1!oid
# oid	Arkan	Arkanoid	#1#	!1!oid
# oid	vocal	vocaloid	#1#	!1!oid
# oid	Cardi	Cardioid	#1#	!1!oid
# oid	ov	ovoid	#1#	!1!oid
# oid	delt	deltoid	#1#	!1!oid
# oid	retin	retinoid	#1#	!1!oid
# oid	kel	keloid	#1#	!1!oid
# oid	Demon	Demonoid	#1#	!1!oid
# oid	r	roid	#1#	!1!oid
# oid	Coll	Colloid	#1#	!1!oid
# oid	Dev	Devoid	#1#	!1!oid
# oid	Amyl	Amyloid	#1#	!1!oid
# oid	chor	choroid	#1#	!1!oid
# oid	schiz	schizoid	#1#	!1!oid
# oid	Trapez	Trapezoid	#1#	!1!oid
# oid	tor	toroid	#1#	!1!oid
# oid	glen	glenoid	#1#	!1!oid
# oid	Schiz	Schizoid	#1#	!1!oid
# oid	spher	spheroid	#1#	!1!oid
# oid	Fact	Factoid	#1#	!1!oid
# oid	cub	cuboid	#1#	!1!oid
# oid	mast	mastoid	#1#	!1!oid
# oid	tox	toxoid	#1#	!1!oid
# oid	Mongol	Mongoloid	#1#	!1!oid
# oid	Z	Zoid	#1#	!1!oid
# oid	demon	demonoid	#1#	!1!oid
# oid	disc	discoid	#1#	!1!oid
# oid	parasit	parasitoid	#1#	!1!oid
# oid	arkan	arkanoid	#1#	!1!oid
# oid	mongol	mongoloid	#1#	!1!oid
# oid	R	Roid	#1#	!1!oid
# oid	planet	planetoid	#1#	!1!oid
# oid	Aner	Aneroid	#1#	!1!oid
# oid	plasm	plasmoid	#1#	!1!oid
# oid	hy	hyoid	#1#	!1!oid
# oid	Negr	Negroid	#1#	!1!oid
# oid	N	Noid	#1#	!1!oid
# oid	Delt	Deltoid	#1#	!1!oid
# oid	meteor	meteoroid	#1#	!1!oid
# oid	ge	geoid	#1#	!1!oid
# oid	Lymph	Lymphoid	#1#	!1!oid
# oid	anthrop	anthropoid	#1#	!1!oid
# oid	Kel	Keloid	#1#	!1!oid
# oid	fr	froid	#1#	!1!oid
# oid	muc	mucoid	#1#	!1!oid
# oid	mon	monoid	#1#	!1!oid
# oid	sinus	sinusoid	#1#	!1!oid
# oid	n	noid	#1#	!1!oid
# oid	insect	insectoid	#1#	!1!oid
# oid	Dt	Dtoid	#1#	!1!oid
# oid	tripl	triploid	#1#	!1!oid
# oid	derm	dermoid	#1#	!1!oid
# oid	group	groupoid	#1#	!1!oid
# oid	aden	adenoid	#1#	!1!oid
# oid	Centr	Centroid	#1#	!1!oid
# oid	rhomb	rhomboid	#1#	!1!oid
# oid	Plasm	Plasmoid	#1#	!1!oid
# oid	Fr	Froid	#1#	!1!oid
# oid	aner	aneroid	#1#	!1!oid
# oid	Meteor	Meteoroid	#1#	!1!oid
# oid	per	peroid	#1#	!1!oid
# oid	Caucas	Caucasoid	#1#	!1!oid
# oid	Dragon	Dragonoid	#1#	!1!oid
# oid	Dipl	Diploid	#1#	!1!oid
# oid	pearl	pearloid	#1#	!1!oid
# oid	parabol	paraboloid	#1#	!1!oid
# oid	sesam	sesamoid	#1#	!1!oid
# oid	Alt	Altoid	#1#	!1!oid
# oid	Cub	Cuboid	#1#	!1!oid
# oid	Grab	Graboid	#1#	!1!oid
# oid	sarc	sarcoid	#1#	!1!oid
# oid	Ellips	Ellipsoid	#1#	!1!oid
# oid	crystall	crystalloid	#1#	!1!oid
# oid	metall	metalloid	#1#	!1!oid
# oid	homin	hominoid	#1#	!1!oid
# oid	Pearl	Pearloid	#1#	!1!oid
# oid	cycl	cycloid	#1#	!1!oid
# oid	myx	myxoid	#1#	!1!oid
# oid	oste	osteoid	#1#	!1!oid
# oid	Retin	Retinoid	#1#	!1!oid
# oid	lymphoblast	lymphoblastoid	#1#	!1!oid
# oid	Tor	Toroid	#1#	!1!oid
# oid	crin	crinoid	#1#	!1!oid
# oid	Disc	Discoid	#1#	!1!oid
# oid	Aden	Adenoid	#1#	!1!oid
# oid	B	Boid	#1#	!1!oid
# oid	z	zoid	#1#	!1!oid
# oid	hyp	hypoid	#1#	!1!oid
# oid	cric	cricoid	#1#	!1!oid
# oid	coron	coronoid	#1#	!1!oid
# oid	Mon	Monoid	#1#	!1!oid
# oid	Rhomb	Rhomboid	#1#	!1!oid
# oid	astr	astroid	#1#	!1!oid
# oid	styl	styloid	#1#	!1!oid
# oid	Zomb	Zomboid	#1#	!1!oid
# oid	polyp	polypoid	#1#	!1!oid
# oid	p	poid	#1#	!1!oid
# oid	thry	thryoid	#1#	!1!oid
# oid	Derm	Dermoid	#1#	!1!oid
# oid	embry	embryoid	#1#	!1!oid
# oid	caucas	caucasoid	#1#	!1!oid
# oid	Gear	Gearoid	#1#	!1!oid
# oid	Ov	Ovoid	#1#	!1!oid
# oid	Arcan	Arcanoid	#1#	!1!oid
# oid	And	Andoid	#1#	!1!oid
# oid	geek	geekoid	#1#	!1!oid
# oid	hydr	hydroid	#1#	!1!oid
# oid	helic	helicoid	#1#	!1!oid
# oid	downl	downloid	#1#	!1!oid
# oid	Tox	Toxoid	#1#	!1!oid
# oid	Ge	Geoid	#1#	!1!oid
# oid	matr	matroid	#1#	!1!oid
# oid	Ter	Teroid	#1#	!1!oid
# oid	Planet	Planetoid	#1#	!1!oid
# oid	vanill	vanilloid	#1#	!1!oid
# oid	Astr	Astroid	#1#	!1!oid
# oid	ivor	ivoroid	#1#	!1!oid
# oid	Hyperball	Hyperballoid	#1#	!1!oid
# oid	block	blockoid	#1#	!1!oid
# oid	destruct	destructoid	#1#	!1!oid
# oid	cyst	cystoid	#1#	!1!oid
# oid	lichen	lichenoid	#1#	!1!oid
# oid	Demant	Demantoid	#1#	!1!oid
# oid	Destr	Destroid	#1#	!1!oid
# oid	Chor	Choroid	#1#	!1!oid
# oid	Ivor	Ivoroid	#1#	!1!oid
# oid	techn	technoid	#1#	!1!oid
# oid	lip	lipoid	#1#	!1!oid
# oid	Adr	Adroid	#1#	!1!oid
# oid	alt	altoid	#1#	!1!oid
# oid	A-R	A-Roid	#1#	!1!oid
# oid	Ox	Oxoid	#1#	!1!oid
# oid	Repl	Reploid	#1#	!1!oid
# oid	shirt	shirtoid	#1#	!1!oid
# oid	Insect	Insectoid	#1#	!1!oid
# oid	Hyp	Hypoid	#1#	!1!oid
# oid	mechan	mechanoid	#1#	!1!oid
# oid	b	boid	#1#	!1!oid
# oid	Crin	Crinoid	#1#	!1!oid
# oid	nucle	nucleoid	#1#	!1!oid
# oid	vir	viroid	#1#	!1!oid
# oid	Mong	Mongoid	#1#	!1!oid
# oid	non-human	non-humanoid	#1#	!1!oid
# oid	ar	aroid	#1#	!1!oid
# oid	Hydr	Hydroid	#1#	!1!oid
# oid	petal	petaloid	#1#	!1!oid
# oid	t	toid	#1#	!1!oid
# oid	Biol	Bioloid	#1#	!1!oid
# oid	Fl	Floid	#1#	!1!oid
# oid	grab	graboid	#1#	!1!oid
# oid	Anthrop	Anthropoid	#1#	!1!oid
# oid	Embr	Embroid	#1#	!1!oid
# oid	cer	ceroid	#1#	!1!oid
# oid	Hal	Haloid	#1#	!1!oid
# oid	Techn	Technoid	#1#	!1!oid
# oid	Retr	Retroid	#1#	!1!oid
# oid	X	Xoid	#1#	!1!oid
# oid	Gyn	Gynoid	#1#	!1!oid
# oid	thr	throid	#1#	!1!oid
# oid	solon	solonoid	#1#	!1!oid
# oid	Loc	Locoid	#1#	!1!oid
# oid	granit	granitoid	#1#	!1!oid
# oid	Cycl	Cycloid	#1#	!1!oid
# oid	Mast	Mastoid	#1#	!1!oid
# oid	Goblin	Goblinoid	#1#	!1!oid
# oid	Cybern	Cybernoid	#1#	!1!oid
# oid	adr	adroid	#1#	!1!oid
# oid	polor	poloroid	#1#	!1!oid
# oid	vide	videoid	#1#	!1!oid
# oid	dragon	dragonoid	#1#	!1!oid
# oid	Glen	Glenoid	#1#	!1!oid
# oid	gyn	gynoid	#1#	!1!oid
# oid	diamond	diamondoid	#1#	!1!oid
# oid	Gator	Gatoroid	#1#	!1!oid
# oid	Henr	Henroid	#1#	!1!oid
# oid	Leather	Leatheroid	#1#	!1!oid
# oid	Ar	Aroid	#1#	!1!oid
# oid	Rept	Reptoid	#1#	!1!oid
# oid	Anr	Anroid	#1#	!1!oid
# oid	zo	zooid	#1#	!1!oid
# oid	Tripl	Triploid	#1#	!1!oid
# oid	repl	reploid	#1#	!1!oid
# oid	Gemin	Geminoid	#1#	!1!oid
# oid	embr	embroid	#1#	!1!oid
# oid	dt	dtoid	#1#	!1!oid
# oid	fung	fungoid	#1#	!1!oid
# oid	#polar	#polaroid	#1#	!1!oid
# oid	Parasit	Parasitoid	#1#	!1!oid
# oid	calan	calanoid	#1#	!1!oid
# oid	funct	functoid	#1#	!1!oid
# oid	basal	basaloid	#1#	!1!oid
# oid	g	goid	#1#	!1!oid
# oid	Bar	Baroid	#1#	!1!oid
# oid	Superv	Supervoid	#1#	!1!oid
# oid	Muc	Mucoid	#1#	!1!oid
# oid	Sarc	Sarcoid	#1#	!1!oid
# oid	resin	resinoid	#1#	!1!oid
# oid	l	loid	#1#	!1!oid
# oid	irid	iridoid	#1#	!1!oid
# oid	Austral	Australoid	#1#	!1!oid
# oid	cocc	coccoid	#1#	!1!oid
# oid	adv	advoid	#1#	!1!oid
# oid	my	myoid	#1#	!1!oid
# oid	Mechan	Mechanoid	#1#	!1!oid
# oid	mong	mongoid	#1#	!1!oid
# oid	C	Coid	#1#	!1!oid
# oid	rept	reptoid	#1#	!1!oid
# oid	selen	selenoid	#1#	!1!oid
# oid	Sinus	Sinusoid	#1#	!1!oid
# oid	bic	bicoid	#1#	!1!oid
# oid	Hy	Hyoid	#1#	!1!oid
# oid	Bic	Bicoid	#1#	!1!oid
# oid	and	andoid	#1#	!1!oid
# oid	Fung	Fungoid	#1#	!1!oid
# oid	L	Loid	#1#	!1!oid
# oid	fibrin	fibrinoid	#1#	!1!oid
# oid	parin	parinoid	#1#	!1!oid
# oid	anr	anroid	#1#	!1!oid
# oid	Adapt	Adaptoid	#1#	!1!oid
# oid	Retron	Retronoid	#1#	!1!oid
# oid	goblin	goblinoid	#1#	!1!oid
# oid	con	conoid	#1#	!1!oid
# oid	Turpen	Turpenoid	#1#	!1!oid
# oid	Helic	Helicoid	#1#	!1!oid
# oid	Oste	Osteoid	#1#	!1!oid
# oid	cushing	cushingoid	#1#	!1!oid
# oid	nev	nevoid	#1#	!1!oid
# oid	Qub	Quboid	#1#	!1!oid
# oid	pept	peptoid	#1#	!1!oid
# oid	Matr	Matroid	#1#	!1!oid
# oid	Salmon	Salmonoid	#1#	!1!oid
# oid	Gilf	Gilfoid	#1#	!1!oid
# oid	s	soid	#1#	!1!oid
# oid	Zo	Zooid	#1#	!1!oid
# oid	phot	photoid	#1#	!1!oid
# oid	Mut	Mutoid	#1#	!1!oid
# oid	Angel	Angeloid	#1#	!1!oid
# oid	organ	organoid	#1#	!1!oid
# oid	Sesam	Sesamoid	#1#	!1!oid
# oid	op	opoid	#1#	!1!oid
# oid	Hydran	Hydranoid	#1#	!1!oid
# oid	Shirt	Shirtoid	#1#	!1!oid
# oid	ava	avaoid	#1#	!1!oid
# oid	f	foid	#1#	!1!oid
# oid	Lip	Lipoid	#1#	!1!oid
# oid	Kof	Kofoid	#1#	!1!oid
# oid	torr	torroid	#1#	!1!oid
# oid	McC	McCoid	#1#	!1!oid
# oid	tyr	tyroid	#1#	!1!oid
# oid	nutz	nutzoid	#1#	!1!oid
# oid	glob	globoid	#1#	!1!oid
# oid	dv	dvoid	#1#	!1!oid
# oid	h	hoid	#1#	!1!oid
# oid	Xiph	Xiphoid	#1#	!1!oid
# oid	N64	N64oid	#1#	!1!oid
# oid	gyr	gyroid	#1#	!1!oid
# oid	stu	stuoid	#1#	!1!oid
# oid	Homin	Hominoid	#1#	!1!oid
# oid	gramin	graminoid	#1#	!1!oid
# oid	w	woid	#1#	!1!oid
# oid	Myx	Myxoid	#1#	!1!oid
# oid	parn	parnoid	#1#	!1!oid
# oid	leather	leatheroid	#1#	!1!oid
# oid	curcumin	curcuminoid	#1#	!1!oid
# oid	d	doid	#1#	!1!oid
# oid	ammon	ammonoid	#1#	!1!oid
# oid	left	leftoid	#1#	!1!oid
# oid	Menz	Menzoid	#1#	!1!oid
# oid	Gyr	Gyroid	#1#	!1!oid
# oid	destr	destroid	#1#	!1!oid
# oid	Plastic	Plasticoid	#1#	!1!oid
# oid	Metall	Metalloid	#1#	!1!oid
# oid	gan	ganoid	#1#	!1!oid
# oid	Cer	Ceroid	#1#	!1!oid
# oid	plac	placoid	#1#	!1!oid
# oid	loc	locoid	#1#	!1!oid
# oid	Numan	Numanoid	#1#	!1!oid
# oid	c	coid	#1#	!1!oid
# oid	Crystall	Crystalloid	#1#	!1!oid
# oid	plut	plutoid	#1#	!1!oid
# oid	ndr	ndroid	#1#	!1!oid
# oid	Ruber	Ruberoid	#1#	!1!oid
# oid	mucin	mucinoid	#1#	!1!oid
# oid	Fugit	Fugitoid	#1#	!1!oid
# oid	Apar	Aparoid	#1#	!1!oid
# oid	M	Moid	#1#	!1!oid
# oid	capsaicin	capsaicinoid	#1#	!1!oid
# oid	Sisk	Siskoid	#1#	!1!oid
# oid	protein	proteinoid	#1#	!1!oid
# oid	Matt	Mattoid	#1#	!1!oid
# oid	paron	paronoid	#1#	!1!oid
# oid	zomb	zomboid	#1#	!1!oid
# oid	cloth	clothoid	#1#	!1!oid
# oid	felin	felinoid	#1#	!1!oid
# oid	Resin	Resinoid	#1#	!1!oid
# oid	P	Poid	#1#	!1!oid
# oid	volto	voltooid	#1#	!1!oid
# oid	Merc	Mercoid	#1#	!1!oid
# oid	Battl	Battloid	#1#	!1!oid
# oid	troch	trochoid	#1#	!1!oid
# oid	Cyst	Cystoid	#1#	!1!oid
# oid	Parabol	Paraboloid	#1#	!1!oid
# oid	Organ	Organoid	#1#	!1!oid
# oid	Kryn	Krynoid	#1#	!1!oid
# oid	albumin	albuminoid	#1#	!1!oid
# oid	Cushing	Cushingoid	#1#	!1!oid
# oid	Enterpr	Enterproid	#1#	!1!oid
# oid	Blogger	Bloggeroid	#1#	!1!oid
# oid	robot	robotoid	#1#	!1!oid
# oid	oval	ovaloid	#1#	!1!oid
# oid	Sect	Sectoid	#1#	!1!oid
# oid	progress	progressoid	#1#	!1!oid
# oid	Therm	Thermoid	#1#	!1!oid
#
#
#
# !1!oid
# #1#um
#
#
#
# oid	vum	void	#1#um	!1!oid
# oid	Drum	Droid	#1#um	!1!oid
# oid	Vum	Void	#1#um	!1!oid
# oid	drum	droid	#1#um	!1!oid
# oid	Metrum	Metroid	#1#um	!1!oid
# oid	opium	opioid	#1#um	!1!oid
# oid	humanum	humanoid	#1#um	!1!oid
# oid	factum	factoid	#1#um	!1!oid
# oid	Humanum	Humanoid	#1#um	!1!oid
# oid	Opium	Opioid	#1#um	!1!oid
# oid	collum	colloid	#1#um	!1!oid
# oid	cardium	cardioid	#1#um	!1!oid
# oid	cannabinum	cannabinoid	#1#um	!1!oid
# oid	centrum	centroid	#1#um	!1!oid
# oid	Cardium	Cardioid	#1#um	!1!oid
# oid	ovum	ovoid	#1#um	!1!oid
# oid	rum	roid	#1#um	!1!oid
# oid	Collum	Colloid	#1#um	!1!oid
# oid	Factum	Factoid	#1#um	!1!oid
# oid	Zum	Zoid	#1#um	!1!oid
# oid	Rum	Roid	#1#um	!1!oid
# oid	pyrethrum	pyrethroid	#1#um	!1!oid
# oid	Num	Noid	#1#um	!1!oid
# oid	geum	geoid	#1#um	!1!oid
# oid	frum	froid	#1#um	!1!oid
# oid	epithelium	epithelioid	#1#um	!1!oid
# oid	num	noid	#1#um	!1!oid
# oid	Centrum	Centroid	#1#um	!1!oid
# oid	Frum	Froid	#1#um	!1!oid
# oid	sesamum	sesamoid	#1#um	!1!oid
# oid	Altum	Altoid	#1#um	!1!oid
# oid	metallum	metalloid	#1#um	!1!oid
# oid	hominum	hominoid	#1#um	!1!oid
# oid	crinum	crinoid	#1#um	!1!oid
# oid	Bum	Boid	#1#um	!1!oid
# oid	zum	zoid	#1#um	!1!oid
# oid	Monum	Monoid	#1#um	!1!oid
# oid	endometrium	endometrioid	#1#um	!1!oid
# oid	astrum	astroid	#1#um	!1!oid
# oid	pum	poid	#1#um	!1!oid
# oid	Ovum	Ovoid	#1#um	!1!oid
# oid	Arcanum	Arcanoid	#1#um	!1!oid
# oid	Geum	Geoid	#1#um	!1!oid
# oid	Astrum	Astroid	#1#um	!1!oid
# oid	altum	altoid	#1#um	!1!oid
# oid	Oxum	Oxoid	#1#um	!1!oid
# oid	bum	boid	#1#um	!1!oid
# oid	Crinum	Crinoid	#1#um	!1!oid
# oid	virum	viroid	#1#um	!1!oid
# oid	arum	aroid	#1#um	!1!oid
# oid	tum	toid	#1#um	!1!oid
# oid	arcanum	arcanoid	#1#um	!1!oid
# oid	Flum	Floid	#1#um	!1!oid
# oid	Xum	Xoid	#1#um	!1!oid
# oid	thrum	throid	#1#um	!1!oid
# oid	Locum	Locoid	#1#um	!1!oid
# oid	Epithelium	Epithelioid	#1#um	!1!oid
# oid	Pyrethrum	Pyrethroid	#1#um	!1!oid
# oid	Arum	Aroid	#1#um	!1!oid
# oid	gum	goid	#1#um	!1!oid
# oid	Barum	Baroid	#1#um	!1!oid
# oid	iDrum	iDroid	#1#um	!1!oid
# oid	lum	loid	#1#um	!1!oid
