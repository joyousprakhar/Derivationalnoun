# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from scipy.sparse import csr_matrix, lil_matrix
from scipy import sparse
from abc import ABCMeta, abstractmethod
from scipy.stats import randint as sp_randint
import random

# %%
# !pip install -q xlrd
# !git clone https://github.com/mansisinha/taddhita.git
# Out:
# fatal: destination path 'taddhita' already exists and is not an empty directory.

# %%
# !ls taddhita/newPairs.txt
# Out:
# taddhita/newPairs.txt

# %%
import pandas as pd
url='https://raw.githubusercontent.com/mansisinha/taddhita/master/allPairs.csv'

df=pd.read_csv(url)
df.drop(['affix','word','sense','meaning','Source Word Count','Derived word count','word_y'],axis=1,inplace=True)
#df['n']=1
df
#df.groupby('Affix').count()
# Out:
#      Affix   Source Word    Derived Word
# 0       ly       selfish       selfishly
# 1       ly      virulent      virulently
# 2       ly        gentle          gently
# 3       ly    harmonious    harmoniously
# 4       ly       guarded       guardedly
# 5       ly       gushing       gushingly
# 6       ly      habitual      habitually
# 7       ly         handy         handily
# 8       ly     haphazard     haphazardly
# 9       ly         happy         happily
# 10      ly       harmful       harmfully
# 11      ly      harmless      harmlessly
# 12      ly         harsh         harshly
# 13      ly      grudging      grudgingly
# 14      ly         hasty         hastily
# 15      ly     hazardous     hazardously
# 16      ly         hedly          headly
# 17      ly     healthful     healthfully
# 18      ly       healthy       healthily
# 19      ly     genocidal     genocidally
# 20      ly  foundational  foundationally
# 21      ly     fortunate     fortunately
# 22      ly          fond          fondly
# 23      ly     voiceless     voicelessly
# 24      ly    vociferous    vociferously
# 25      ly         vocal         vocally
# 26      ly    viviparous    viviparously
# 27      ly         vivid         vividly
# 28      ly     vivacious     vivaciously
# 29      ly       visible         visibly
# ...    ...           ...             ...
# 7485   ism    terrorisme       terrorism
# 7486   ism          lyre          lyrism
# 7487     y           pig           piggy
# 7488     y          pike           pikey
# 7489     y           pom           pommy
# 7490     y         prose           prosy
# 7491     y  ambidextrous            amby
# 7492     y           dun           dunny
# 7493     y          goon           goony
# 7494     y          mess           messy
# 7495     y        ignore            iggy
# 7496     y        nigger           niggy
# 7497     y          hunk           hunky
# 7498   ism      plagiary      plagiarism
# 7499   ism     commensal    commensalism
# 7500   ous         usury        usurious
# 7501   ism          tour         tourism
# 7502   ism     triumphal    triumphalism
# 7503   ism      creation     creationism
# 7504   ous          cone      coniferous
# 7505   ous      idolatry      idolatrous
# 7506   ous        fibrin       fibrinous
# 7507   ous       festive       festivous
# 7508  wise           fan         fanwise
# 7509   ous        clamor       clamorous
# 7510   ous    androgynus     androgynous
# 7511   ous       albumin      albuminous
# 7512   ous       acronym      acronymous
# 7513   ous       alumina       aluminous
# 7514   ous     pseudonym    pseudonymous
#
# [7515 rows x 3 columns]

# %%
# Iterative longest contiguous sequence. No one character matchings
def lcs(s1,s2):
    longest = ""
    i = 0
    for x in s1:
        if re.search(x, s2):
          s = x
          while re.search(s, s2):
            if len(s)>len(longest):
                longest = s
            if i+len(s) == len(s1):
                break
            s = s1[i:i+len(s)+1]
        i += 1
    return longest

def iterLCS(pdf):
    posCounter = 1
    sw1Orig = pdf['Source Word']
    sw2Orig = pdf['Derived Word']
    sw1 = pdf['Source Word']
    sw2 = pdf['Derived Word']
    longDict = dict()
    prevSInd = 0
    prevTInd = 0
    rejLength =0
    
    while True:
        tempVal = lcs(sw1Orig,sw2Orig)
        if len(tempVal)  <= 1:
            break
        
        tempSInd =  pdf['Source Word'].find(tempVal) + 1
        tempTInd =  pdf['Derived Word'].find(tempVal) + 1
        if (tempSInd - prevSInd)*(tempTInd - prevTInd) < 0:
            print('here',tempVal,pdf['Source Word'],pdf['Derived Word'])
            sw1Orig = sw1Orig.replace(tempVal,'~~',1)
            sw2Orig = sw2Orig.replace(tempVal,'^^',1)
            rejLength += len(tempVal)
        else:
            longDict[tempSInd] = tempVal+'#'+str(posCounter)
            sw1 = sw1.replace(tempVal,'#'+str(posCounter)+'#',1)
            sw2 = sw2.replace(tempVal,'!'+str(posCounter)+'!',1)
            sw1Orig = sw1Orig.replace(tempVal,'~'+str(posCounter)+'~',1)
            sw2Orig = sw2Orig.replace(tempVal,'^'+str(posCounter)+'^',1)
            prevSInd = tempSInd + 1
            prevTInd = tempTInd + 1
            posCounter += 1
    
    #return [longList,[item for item in sw1.split('#') if len(item) > 0],[item for item in sw2.split('!') if len(item) > 0]]
    pdf['common'] = longDict
    pdf['deleted'] = [item for item in sw1.split('#') if len(item) > 0 and item.isdigit()!=True ]
    pdf['sourceSkeleton'] = sw1
    pdf['targetSkeleton'] = sw2
    

    jointWord = ''
    sw1Split = sw1.split('#')
    sw2Split = sw2.split('!')
    
    sw3 = [nummi for nummi in sw1Split if nummi.isdigit() == True]
    sw4 = [nummi for nummi in sw2Split if nummi.isdigit() == True]
    
    if sw3!=sw4:
            print('ordermatchilla',sw3,sw4)
    

    for key in sorted(longDict.keys()):
        nowN = longDict[key].split('#')[1]
        try:
            
            while sw1Split[0] != nowN:
            
                tingi = sw1Split.pop(0)
                if len(tingi) > 0:
                    
                    jointWord += 'DEL('
                    for cahra in tingi:
                        jointWord += cahra
                    jointWord += ')'
        except IndexError:
            print("SW1",pdf['Source Word'])
                
        try:
            while sw2Split[0] != nowN:
                tingi = sw2Split.pop(0)
                if len(tingi) > 0:
                    jointWord += 'INS('
                    for cahra in tingi:
                        jointWord += cahra
                    jointWord += ')'
        except IndexError:
            print("SW2",pdf['source'])
            
            
        try:    
            if  sw1Split[0] == nowN and  sw2Split[0] == nowN:
                jointWord = jointWord + longDict[key].split('#')[0]
                sw1Split.pop(0)
                sw2Split.pop(0)
            else:
                print('pani pali not expected')
        except IndexError:
            print("common",pdf['Source Word'])
                
    while len(sw1Split) > 0:
        tingi = sw1Split.pop(0)
        if len(tingi) > 0:
            jointWord += 'DEL('
            for cahra in tingi:
                jointWord += cahra
            jointWord += ')'
            
    while len(sw2Split) > 0:
        
        tingi = sw2Split.pop(0)
        if len(tingi) > 0:
            jointWord += 'INS('
            for cahra in tingi:
                jointWord += cahra
            jointWord += ')'

    
    if len(pdf['deleted']) == 0:
        pdf['deleted'] = ['ϵ']
    
    
    pdf['added'] = [item for item in sw2.split('!') if len(item) > 0 and item.isdigit()!=True]
    
    if len(pdf['added']) == 0:
        pdf['added'] = ['ϵ']
        
    pdf['aligned'] = jointWord
    
    return pdf
    
#iterLCS(ppd.iloc[3865,:])

# %%
import re
df12=df.sample(frac=1)
ddf = df12.apply(iterLCS, axis=1)

# %%
ddf
# Out:
#       Affix      Source Word       Derived Word                    common  \
# 2851    ist        handcycle        handcyclist         {1: 'handcycl#1'}
# 6323   hood          prophet        prophethood          {1: 'prophet#1'}
# 4803     ee             hire              hiree             {1: 'hire#1'}
# 4821     ee            crush            crushee            {1: 'crush#1'}
# 1156     ly        ambiguous        ambiguously        {1: 'ambiguous#1'}
# 3962   ness             fake           fakeness             {1: 'fake#1'}
# 3110     ly          certain          certainly          {1: 'certain#1'}
# 1062     ly        memorable          memorably         {1: 'memorabl#1'}
# 1066     ly      injudicious      injudiciously      {1: 'injudicious#1'}
# 3396   ness             idle           idleness             {1: 'idle#1'}
# 2139     er           derail           derailer           {1: 'derail#1'}
# 6608   ally    diffeomorphic  diffeomorphically    {1: 'diffeomorphic#1'}
# 421      ly       phenomenal       phenomenally       {1: 'phenomenal#1'}
# 3782   ness       memoryless     memorylessness       {1: 'memoryless#1'}
# 128      ly            fresh            freshly            {1: 'fresh#1'}
# 4457    man             flag            flagman             {1: 'flag#1'}
# 6932  proof           grease        greaseproof           {1: 'grease#1'}
# 729      ly          sketchy          sketchily           {1: 'sketch#1'}
# 6085   ster             zine           zinester             {1: 'zine#1'}
# 475      ly       prodigious       prodigiously       {1: 'prodigious#1'}
# 3639     er            bound            bounder            {1: 'bound#1'}
# 4114   ally          satiric        satirically          {1: 'satiric#1'}
# 6636    oid         nautilus          nautiloid           {1: 'nautil#1'}
# 613      ly  disadvantageous  disadvantageously  {1: 'disadvantageous#1'}
# 1953     er          salvage           salvager          {1: 'salvage#1'}
# 6635    oid        epileptic         epileptoid          {1: 'epilept#1'}
# 5619    ity            rural           rurality            {1: 'rural#1'}
# 5626    ity          nuptial         nuptiality          {1: 'nuptial#1'}
# 283      ly       voluptuous       voluptuously       {1: 'voluptuous#1'}
# 5557   ally    electrophilic  electrophilically    {1: 'electrophilic#1'}
# ...     ...              ...                ...                       ...
# 3285     ic           amulet           amuletic           {1: 'amulet#1'}
# 142      ly         credible           credibly          {1: 'credibl#1'}
# 7491      y     ambidextrous               amby              {1: 'amb#1'}
# 7293    age             soak            soakage             {1: 'soak#1'}
# 4888     ly             main             mainly             {1: 'main#1'}
# 5199   like            sheep          sheeplike            {1: 'sheep#1'}
# 276      ly            weird            weirdly            {1: 'weird#1'}
# 2267     er             dice              dicer             {1: 'dice#1'}
# 6844      y           billow            billowy           {1: 'billow#1'}
# 785      ly      synchronous      synchronously      {1: 'synchronous#1'}
# 2853    ist          harmony          harmonist           {1: 'harmon#1'}
# 7039      y             noob              nooby             {1: 'noob#1'}
# 5015     ly            great            greatly            {1: 'great#1'}
# 345      ly   methodological   methodologically   {1: 'methodological#1'}
# 145      ly          corrupt          corruptly          {1: 'corrupt#1'}
# 727      ly           skimpy           skimpily            {1: 'skimp#1'}
# 3269     ic     hyperalgesia       hyperalgesic      {1: 'hyperalgesi#1'}
# 1612     er           assert           asserter           {1: 'assert#1'}
# 1403     er             melt             melter             {1: 'melt#1'}
# 2128     er          restart          restarter          {1: 'restart#1'}
# 5088  ation      desulfurize    desulfurization       {1: 'desulfuriz#1'}
# 593      ly          sincere          sincerely          {1: 'sincere#1'}
# 325      ly          comrade          comradely          {1: 'comrade#1'}
# 5583   ship             clan           clanship             {1: 'clan#1'}
# 979      ly         atypical         atypically         {1: 'atypical#1'}
# 3844     er           duplex           duplexer           {1: 'duplex#1'}
# 2530   ness         deserved       deservedness         {1: 'deserved#1'}
# 296      ly   unsatisfactory   unsatisfactorily    {1: 'unsatisfactor#1'}
# 1284     ly    chronological    chronologically    {1: 'chronological#1'}
# 3090     ly           mortal           mortally           {1: 'mortal#1'}
#
#           deleted sourceSkeleton targetSkeleton    added  \
# 2851          [e]           #1#e         !1!ist    [ist]
# 6323          [ϵ]            #1#        !1!hood   [hood]
# 4803          [ϵ]            #1#           !1!e      [e]
# 4821          [ϵ]            #1#          !1!ee     [ee]
# 1156          [ϵ]            #1#          !1!ly     [ly]
# 3962          [ϵ]            #1#        !1!ness   [ness]
# 3110          [ϵ]            #1#          !1!ly     [ly]
# 1062          [e]           #1#e           !1!y      [y]
# 1066          [ϵ]            #1#          !1!ly     [ly]
# 3396          [ϵ]            #1#        !1!ness   [ness]
# 2139          [ϵ]            #1#          !1!er     [er]
# 6608          [ϵ]            #1#        !1!ally   [ally]
# 421           [ϵ]            #1#          !1!ly     [ly]
# 3782          [ϵ]            #1#        !1!ness   [ness]
# 128           [ϵ]            #1#          !1!ly     [ly]
# 4457          [ϵ]            #1#         !1!man    [man]
# 6932          [ϵ]            #1#       !1!proof  [proof]
# 729           [y]           #1#y         !1!ily    [ily]
# 6085          [ϵ]            #1#        !1!ster   [ster]
# 475           [ϵ]            #1#          !1!ly     [ly]
# 3639          [ϵ]            #1#          !1!er     [er]
# 4114          [ϵ]            #1#        !1!ally   [ally]
# 6636         [us]          #1#us         !1!oid    [oid]
# 613           [ϵ]            #1#          !1!ly     [ly]
# 1953          [ϵ]            #1#           !1!r      [r]
# 6635         [ic]          #1#ic         !1!oid    [oid]
# 5619          [ϵ]            #1#         !1!ity    [ity]
# 5626          [ϵ]            #1#         !1!ity    [ity]
# 283           [ϵ]            #1#          !1!ly     [ly]
# 5557          [ϵ]            #1#        !1!ally   [ally]
# ...           ...            ...            ...      ...
# 3285          [ϵ]            #1#          !1!ic     [ic]
# 142           [e]           #1#e           !1!y      [y]
# 7491  [idextrous]   #1#idextrous           !1!y      [y]
# 7293          [ϵ]            #1#         !1!age    [age]
# 4888          [ϵ]            #1#          !1!ly     [ly]
# 5199          [ϵ]            #1#        !1!like   [like]
# 276           [ϵ]            #1#          !1!ly     [ly]
# 2267          [ϵ]            #1#           !1!r      [r]
# 6844          [ϵ]            #1#           !1!y      [y]
# 785           [ϵ]            #1#          !1!ly     [ly]
# 2853          [y]           #1#y         !1!ist    [ist]
# 7039          [ϵ]            #1#           !1!y      [y]
# 5015          [ϵ]            #1#          !1!ly     [ly]
# 345           [ϵ]            #1#          !1!ly     [ly]
# 145           [ϵ]            #1#          !1!ly     [ly]
# 727           [y]           #1#y         !1!ily    [ily]
# 3269          [a]           #1#a           !1!c      [c]
# 1612          [ϵ]            #1#          !1!er     [er]
# 1403          [ϵ]            #1#          !1!er     [er]
# 2128          [ϵ]            #1#          !1!er     [er]
# 5088          [e]           #1#e       !1!ation  [ation]
# 593           [ϵ]            #1#          !1!ly     [ly]
# 325           [ϵ]            #1#          !1!ly     [ly]
# 5583          [ϵ]            #1#        !1!ship   [ship]
# 979           [ϵ]            #1#          !1!ly     [ly]
# 3844          [ϵ]            #1#          !1!er     [er]
# 2530          [ϵ]            #1#        !1!ness   [ness]
# 296           [y]           #1#y         !1!ily    [ily]
# 1284          [ϵ]            #1#          !1!ly     [ly]
# 3090          [ϵ]            #1#          !1!ly     [ly]
#
#                           aligned
# 2851       handcyclDEL(e)INS(ist)
# 6323             prophetINS(hood)
# 4803                   hireINS(e)
# 4821                 crushINS(ee)
# 1156             ambiguousINS(ly)
# 3962                fakeINS(ness)
# 3110               certainINS(ly)
# 1062         memorablDEL(e)INS(y)
# 1066           injudiciousINS(ly)
# 3396                idleINS(ness)
# 2139                derailINS(er)
# 6608       diffeomorphicINS(ally)
# 421             phenomenalINS(ly)
# 3782          memorylessINS(ness)
# 128                  freshINS(ly)
# 4457                 flagINS(man)
# 6932             greaseINS(proof)
# 729          sketchDEL(y)INS(ily)
# 6085                zineINS(ster)
# 475             prodigiousINS(ly)
# 3639                 boundINS(er)
# 4114             satiricINS(ally)
# 6636        nautilDEL(us)INS(oid)
# 613        disadvantageousINS(ly)
# 1953                salvageINS(r)
# 6635       epileptDEL(ic)INS(oid)
# 5619                ruralINS(ity)
# 5626              nuptialINS(ity)
# 283             voluptuousINS(ly)
# 5557       electrophilicINS(ally)
# ...                           ...
# 3285                amuletINS(ic)
# 142           crediblDEL(e)INS(y)
# 7491      ambDEL(idextrous)INS(y)
# 7293                 soakINS(age)
# 4888                  mainINS(ly)
# 5199               sheepINS(like)
# 276                  weirdINS(ly)
# 2267                   diceINS(r)
# 6844                 billowINS(y)
# 785            synchronousINS(ly)
# 2853         harmonDEL(y)INS(ist)
# 7039                   noobINS(y)
# 5015                 greatINS(ly)
# 345         methodologicalINS(ly)
# 145                corruptINS(ly)
# 727           skimpDEL(y)INS(ily)
# 3269      hyperalgesiDEL(a)INS(c)
# 1612                assertINS(er)
# 1403                  meltINS(er)
# 2128               restartINS(er)
# 5088   desulfurizDEL(e)INS(ation)
# 593                sincereINS(ly)
# 325                comradeINS(ly)
# 5583                clanINS(ship)
# 979               atypicalINS(ly)
# 3844                duplexINS(er)
# 2530            deservedINS(ness)
# 296   unsatisfactorDEL(y)INS(ily)
# 1284         chronologicalINS(ly)
# 3090                mortalINS(ly)
#
# [7515 rows x 9 columns]

# %%
pattern ={}
for index, row in ddf.iterrows():
    if row['targetSkeleton'] in pattern:
            pattern[row['targetSkeleton']]
            if row['sourceSkeleton'] in pattern[row['targetSkeleton']]:
                pattern[row['targetSkeleton']][row['sourceSkeleton']].add(row['Affix'])
            else:
            continue
        glovewords[line[0]] = []

# %%
def lcs1(X, Y, m, n): 
    L = [[0 for x in range(n+1)] for x in range(m+1)]   
    for i in range(m+1): 
        for j in range(n+1): 
            if i == 0 or j == 0: 
                L[i][j] = 0
            elif X[i-1] == Y[j-1]: 
                L[i][j] = L[i-1][j-1] + 1
            else: 
                L[i][j] = max(L[i-1][j], L[i][j-1])  
    index = L[m][n]  
    lcs = [""] * (index+1) 
    lcs[index] = "" 
    i = m 
    j = n 
    left=[]
    flag=1
    flag1=0
    right=[]
    while i > 0 and j > 0: 
        #print(X[i-1],' ',Y[j-1])
        if X[i-1] == Y[j-1]: 
            lcs[index-1] = X[i-1] 
            i-=1
            right.extend(Y[j-1])
            j-=1
            index-=1
            if i==0 :
                #print(',')
                left.extend(',')
            flag=0
            flag1=0
        elif L[i-1][j] > L[i][j-1]:
            if flag==0:
                left.extend(',')
                flag=1
            if flag1==0:
                right.extend(',')
                flag1=1
            i-=1
        else:
            if flag==0:
                #print(',')
                left.extend(',')
                flag=1
            if flag1==0:
                right.extend(',')
                flag1=1
            left.extend(Y[j-1])
            j-=1
    while i > 0:
        i-=1
    while j > 0:
        left.extend(Y[j-1])
        j-=1
    string="".join(left)
    string1=string[::-1]
    string5="".join(right)
    string6=string5[::-1]
#     print(string6)
    string2=[]
    i=0
    while i<(len(X)):
        if X[i]=='!':
            if i!=0:
                string2.extend(','+X[i]+X[i+1]+X[i+2])
            else:
                string2.extend(X[i]+X[i+1]+X[i+2])
            i+=3
        else:
            i+=1
    if(X[i-1])!='!':
        string2.extend(',')
    string3="".join(string2)
    return "".join(lcs),string1,string3,string6

# %%
str1='!2!page!4!ion'
str2='agetyuion'
print(lcs1(str1,str2,len(str1),len(str2)))
# Out:
# ('ageion', 'tyu,', '!2!,!4!,', 'age,ion')

# %%
def check(x,y):
    z,w,u,v=lcs1(x,y,len(x),len(y))
    u=u.split(',')
    w=w.split(',')
#     print(u)
#     print(w)
    if(len(w)!=len(u)):
        return -1
    t=[]
    t.append([])
    i=0
    j=0
    while i <len(x):
        if x[i]=='!':
            if(i!=0):
                t[j]="".join(t[j])
            i+=3
            j+=1
            t.append([])
        else:
            t[j].extend(x[i])
            i+=1
    t[j]="".join(t[j])
#     print(t)
    v=v.split(',')
#     print(v)
    i=0
    while i <len(t):
        try:
            if len(t[i])==0 and v[i]!='':
                return -1
            elif  len(t[i])!=0 and v[i]=='':
                return -1
            elif  len(t[i])==0 and v[i]=='':
                i+=1
                continue
            elif t[i]!=v[i]:
                return -1
        except IndexError:
            return -1
        i+=1
    
    i=0
    p=[]
    while i<len(w):
        if w[i]=='' and u[i]!='':
            return -1
        elif w[i]!='' and u[i]=='':
            return -1
        if w[i]=='' and u[i]=='':
            i+=1
            continue
        p.append(w[i])
        i+=1
    
    return p

# %%
check('xy!2!ty!3!ui','xybaatyerui')
# Out:
# ['baa', 'er']

# %%
def add(X,Y):
    i=0 
    j=0
    while i<(len(X)):
        if X[i]=='#':
            i+=3
            j+=1
        else:
            i+=1
    string2=[]
    for i in range(j+1) :
        string2.append([])
#     print(string2)
    i=j=0
    while i<(len(X)):
        if X[i]=='#':
            j+=1
            i+=3
        else:
            string2[j].extend(X[i])
            i+=1
#     print(j)
#     print(len(Y))
    if (j)!=(len(Y)):
        return -1
#     print(string2)
    z=[]
    i=0
    while i < j:
        z.extend(string2[i])
        z.extend(Y[i])
        i+=1
    z.extend(string2[i])
    return "".join(z)

# %%
def transform(x,y):
    X=x[0]
    Y=check(X,y)
    if(Y==-1):
        return -1
#     print(x[0])
#     print(Y)
    z=add(x[1],Y)
    return z

# %%
# a=pattern.pop()
# pattern.add(a)
# print(a)
a=('in#1##2#', 'bo!1!in!2!')
pat=['!1!page','#1#']
string='packpage'
transform(pat,string)
# Out:
# 'pack'

# %%
print(pattern)
# Out:
# {'!1!ist': {'#1#e': {'ist'}, '#1#': {'ist'}, '#1#y': {'ist'}, '#1#us': {'ist'}, '#1#o': {'ist'}, '#1#a': {'ist'}, '#1#s': {'ist'}}, '!1!hood': {'#1#': {'hood'}}, '!1!e': {'#1#': {'ee'}, '#1#r': {'ee'}}, '!1!ee': {'#1#': {'ee'}, '#1#or': {'ee'}, '#1#ate': {'ee'}}, '!1!ly': {'#1#': {'y', 'ally', 'ly'}, '#1#ed': {'ly'}}, '!1!ness': {'#1#': {'ness'}, '#1#e': {'ness'}}, '!1!y': {'#1#e': {'y', 'ly'}, '#1#': {'y', 'ly'}, '#1#i': {'y'}, '#1#er': {'y'}, '#1#ey': {'y', 'ly'}, '#1#as': {'ity'}, '#1#idextrous': {'y'}}, '!1!er': {'#1#': {'er'}, '#1#y': {'er'}, '#1#ational': {'er'}, '#1#or': {'er'}, 'bal#1#': {'er'}, '#1#our': {'er'}}, '!1!ally': {'#1#': {'ally', 'ly'}}, '!1!man': {'#1#': {'man'}}, '!1!proof': {'#1#': {'proof'}}, '!1!ily': {'#1#y': {'ly'}}, '!1!ster': {'#1#': {'ster'}}, '!1!oid': {'#1#us': {'oid'}, '#1#ic': {'oid'}, '#1#ium': {'oid'}, '#1#': {'oid'}, '#1#e': {'oid'}, '#1#um': {'oid'}, '#1#ia': {'oid'}, '#1#eus': {'oid'}, '#1#ie': {'oid'}, '#1#ical': {'oid'}, '#1#i': {'oid'}}, '!1!r': {'#1#': {'er'}, '#1#s': {'er'}}, '!1!ity': {'#1#': {'ity'}, '#1#e': {'ity'}, '#1#y': {'ity'}}, '!1!iness': {'#1#y': {'ness'}}, '!1!headedness': {'#1#': {'ness'}}, '!1!ment': {'#1#': {'ment'}, '#1#e': {'ment'}, '#1#l': {'ment'}, '#1#d': {'ment'}, '#1#r': {'ment'}}, '!1!ism': {'#1#': {'ism'}, '#1#e': {'ism'}, '#1#y': {'ism'}, '#1#ese': {'ism'}, '#1#a': {'ism'}}, '!1!or': {'#1#e': {'or'}, '#1#': {'or'}, '#1#eur': {'or'}}, '!1!like': {'#1#': {'like'}}, '!1!ic': {'#1#y': {'ic'}, '#1#': {'ic'}, '#1#e': {'ic'}, '#1#en': {'ic'}, '#1#ue': {'ic'}, '#1#us': {'ic'}, '#1#a': {'ic'}, '#1#on': {'ic'}, '#1#os
1#': {'o'}}, '!1!tic': {'#1#cy': {'ic'}, '#1#': {'ic'}, '#1#sis': {'ic'}, '#1#m': {'ic'}, '#1#s': {'ic'}}, '!2!!1!ness': {'#2#s#1#': {'ness'}}, '!1!age': {'#1#': {'age'}, '#1#e': {'age'}}, '!1!an': {'#1#us': {'an'}, '#1#': {'an'}, '#1#e': {'an'}}, 'au!1!': {'o#1#': {'al'}} ...

# %%
# i=0
for p, value in pattern.items():
    for q, affixset in value.items():
        pat=[p,q]
#         i=0
        print('\n\n')
        print(pat[0])
        print(pat[1])
        print('\n\n')
        for der in glovewords:
#             if(i==5):
#                 break
    #         print(der,end='\t')
            a=transform(pat,der)
    #         print(a)
            if a==-1:
                continue
            try:
                i+=1
                glovewords[a]
                for val in affixset: 
                    print(val,end='\t')
                    print(a,end='\t')
                    print(der,end='\t')
                    print(pat[1],end='\t')
                    print(pat[0])
            except KeyError:
                pass
# Out:
# !1!ist
# #1#e
#
#
#
# ist	le	list	#1#e	!1!ist
# ist	Le	List	#1#e	!1!ist
# ist	arte	artist	#1#e	!1!ist
# ist	asse	assist	#1#e	!1!ist
# ist	exe	exist	#1#e	!1!ist
# ist	Arte	Artist	#1#e	!1!ist
# ist	speciale	specialist	#1#e	!1!ist
# ist	toure	tourist	#1#e	!1!ist
# ist	terrore	terrorist	#1#e	!1!ist
# ist	twe	twist	#1#e	!1!ist
# ist	Speciale	Specialist	#1#e	!1!ist
# ist	rese	resist	#1#e	!1!ist
# ist	wae	waist	#1#e	!1!ist
# ist	race	racist	#1#e	!1!ist
# ist	dente	dentist	#1#e	!1!ist
# ist	conse	consist	#1#e	!1!ist
# ist	wre	wrist	#1#e	!1!ist
# ist	Methode	Methodist	#1#e	!1!ist
# ist	active	activist	#1#e	!1!ist
# ist	inse	insist	#1#e	!1!ist
# ist	guitare	guitarist	#1#e	!1!ist
# ist	Asse	Assist	#1#e	!1!ist
# ist	Toure	Tourist	#1#e	!1!ist
# ist	Commune	Communist	#1#e	!1!ist
# ist	moe	moist	#1#e	!1!ist
# ist	fe	fist	#1#e	!1!ist
# ist	he	hist	#1#e	!1!ist
# ist	sociale	socialist	#1#e	!1!ist
# ist	flore	florist	#1#e	!1!ist
# ist	Twe	Twist	#1#e	!1!ist
# ist	Flore	Florist	#1#e	!1!ist
# ist	femine	feminist	#1#e	!1!ist
# ist	commune	communist	#1#e	!1!ist
# ist	Therape	Therapist	#1#e	!1!ist
# ist	Dente	Dentist	#1#e	!1!ist
# ist	pharmace	pharmacist	#1#e	!1!ist
# ist	me	mist	#1#e	!1!ist
# ist	capitale	capitalist	#1#e	!1!ist
# ist	vocale	vocalist	#1#e	!1!ist
# ist	Sociale	Socialist	#1#e	!1!ist
# ist	Playle	Playlist	#1#e	!1!ist
# ist	perse	persist	#1#e	!1!ist
# ist	Wre	Wrist	#1#e	!1!ist
# ist	Me	Mist	#1#e	!1!ist
# ist	Wae	Waist	#1#e	!1!ist
# ist	style	stylist	#1#e	!1!ist
# ist	basse	bassist	#1#e	!1!ist
# ist	finale	finalist	#1#e	!1!ist
# ist	Kahane	Kahanist	#1#e	!1!ist
# ist	catle	catlist	#1#e	!1!ist
# ist	newsle	newslist	#1#e	!1!ist
# ist	casue	casuist	#1#e	!1!ist
# ist	#Le	#List	#1#e	!1!ist
# ist	gle	glist	#1#e	!1!ist
# ist	tenore	tenorist	#1#e	!1!ist
# ist	violone	violonist	#1#e	!1!ist
# ist	Lumine	Luminist	#1#e	!1!ist
# ist	Pre	Prist	#1#e	!1!ist
# ist	Swe	Swist	#1#e	!1!ist
# ist	Hygene	Hygenist	#1#e	!1!ist
# ist	connective	connectivist	#1#e	!1!ist
# ist	Arsenale	Arsenalist	#1#e	!1!ist
# ist	Lifestyle	Lifestylist	#1#e	!1!ist
# ist	Kommune	Kommunist	#1#e	!1!ist
# ist	table	tablist	#1#e	!1!ist
# ist	Dre	Drist	#1#e	!1!ist
# ist	Narrative	Narrativist	#1#e	!1!ist
# ist	distribute	distributist	#1#e	!1!ist
# ist	Collagene	Collagenist	#1#e	!1!ist
# ist	Bape	Bapist	#1#e	!1!ist
# ist	Hre	Hrist	#1#e	!1!ist
# ist	Vibraphone	Vibraphonist	#1#e	!1!ist
# ist	Comune	Comunist	#1#e	!1!ist
# ist	Vortice	Vorticist	#1#e	!1!ist
# ist	expressive	expressivist	#1#e	!1!ist
# ist	monologue	monologuist	#1#e	!1!ist
# ist	Timpane	Timpanist	#1#e	!1!ist
# ist	spectroscope	spectroscopist	#1#e	!1!ist
# ist	independente	independentist	#1#e	!1!ist
# ist	atome	atomist	#1#e	!1!ist
# ist	trampoline	trampolinist	#1#e	!1!ist
# ist	animale	animalist	#1#e	!1!ist
# ist	centere	centerist	#1#e	!1!ist
# ist	Flume	Flumist	#1#e	!1!ist
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-d936a29fd9f7> in <module>
#      12 #                 break
#      13     #         print(der,end='\t')
# ---> 14             a=transform(pat,der)
#      15     #         print(a)
#      16             if a==-1:
#
# <ipython-input-17-3985b48fef34> in transform(x, y)
#       1 def transform(x,y):
#       2     X=x[0]
# ----> 3     Y=check(X,y)
#       4     if(Y==-1):
#       5         return -1
#
# <ipython-input-14-4bceb3a5d846> in check(x, y)
#       1 def check(x,y):
# ----> 2     z,w,u,v=lcs1(x,y,len(x),len(y))
#       3     u=u.split(',')
#       4     w=w.split(',')
#       5 #     print(u)
#
# <ipython-input-12-3a7b278af984> in lcs1(X, Y, m, n)
#       1 def lcs1(X, Y, m, n):
# ----> 2     L = [[0 for x in range(n+1)] for x in range(m+1)]
#       3     for i in range(m+1):
#       4         for j in range(n+1):
#       5             if i == 0 or j == 0:
#
# <ipython-input-12-3a7b278af984> in <listcomp>(.0)
#       1 def lcs1(X, Y, m, n):
# ----> 2     L = [[0 for x in range(n+1)] for x in range(m+1)]
#       3     for i in range(m+1):
#       4         for j in range(n+1):
#       5             if i == 0 or j == 0:
#
# <ipython-input-12-3a7b278af984> in <listcomp>(.0)
#       1 def lcs1(X, Y, m, n):
# ----> 2     L = [[0 for x in range(n+1)] for x in range(m+1)]
#       3     for i in range(m+1):
#       4         for j in range(n+1):
#       5             if i == 0 or j == 0:
#
# KeyboardInterrupt:
